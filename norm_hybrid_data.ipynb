# %%
tips = [
["Total Bill","Tip","Payer Gender","Payer Smoker","Day of Week","Meal","Party Size"],
[16.99,1.01,"Female","Non-Smoker","Sunday","Dinner",2],
[10.34,1.66,"Male","Non-Smoker","Sunday","Dinner",3],
[21.01,3.5,"Male","Non-Smoker","Sunday","Dinner",3],
[23.68,3.31,"Male","Non-Smoker","Sunday","Dinner",2],
[24.59,3.61,"Female","Non-Smoker","Sunday","Dinner",4],
[25.29,4.71,"Male","Non-Smoker","Sunday","Dinner",4],
[8.77,2,"Male","Non-Smoker","Sunday","Dinner",2],
[26.88,3.12,"Male","Non-Smoker","Sunday","Dinner",4],
[15.04,1.96,"Male","Non-Smoker","Sunday","Dinner",2],
[14.78,3.23,"Male","Non-Smoker","Sunday","Dinner",2],
[10.27,1.71,"Male","Non-Smoker","Sunday","Dinner",2],
[35.26,5,"Female","Non-Smoker","Sunday","Dinner",4],
[15.42,1.57,"Male","Non-Smoker","Sunday","Dinner",2],
[18.43,3,"Male","Non-Smoker","Sunday","Dinner",4],
[14.83,3.02,"Female","Non-Smoker","Sunday","Dinner",2],
[21.58,3.92,"Male","Non-Smoker","Sunday","Dinner",2],
[10.33,1.67,"Female","Non-Smoker","Sunday","Dinner",3],
[16.29,3.71,"Male","Non-Smoker","Sunday","Dinner",3],
[16.97,3.5,"Female","Non-Smoker","Sunday","Dinner",3],
[20.65,3.35,"Male","Non-Smoker","Saturday","Dinner",3],
[17.92,4.08,"Male","Non-Smoker","Saturday","Dinner",2],
[20.29,2.75,"Female","Non-Smoker","Saturday","Dinner",2],
[15.77,2.23,"Female","Non-Smoker","Saturday","Dinner",2],
[39.42,7.58,"Male","Non-Smoker","Saturday","Dinner",4],
[19.82,3.18,"Male","Non-Smoker","Saturday","Dinner",2],
[17.81,2.34,"Male","Non-Smoker","Saturday","Dinner",4],
[13.37,2,"Male","Non-Smoker","Saturday","Dinner",2],
[12.69,2,"Male","Non-Smoker","Saturday","Dinner",2],
[21.7,4.3,"Male","Non-Smoker","Saturday","Dinner",2],
[19.65,3,"Female","Non-Smoker","Saturday","Dinner",2],
[9.55,1.45,"Male","Non-Smoker","Saturday","Dinner",2],
[18.35,2.5,"Male","Non-Smoker","Saturday","Dinner",4],
[15.06,3,"Female","Non-Smoker","Saturday","Dinner",2],
[20.69,2.45,"Female","Non-Smoker","Saturday","Dinner",4],
[17.78,3.27,"Male","Non-Smoker","Saturday","Dinner",2],
[24.06,3.6,"Male","Non-Smoker","Saturday","Dinner",3],
[16.31,2,"Male","Non-Smoker","Saturday","Dinner",3],
[16.93,3.07,"Female","Non-Smoker","Saturday","Dinner",3],
[18.69,2.31,"Male","Non-Smoker","Saturday","Dinner",3],
[31.27,5,"Male","Non-Smoker","Saturday","Dinner",3],
[16.04,2.24,"Male","Non-Smoker","Saturday","Dinner",3],
[17.46,2.54,"Male","Non-Smoker","Sunday","Dinner",2],
[13.94,3.06,"Male","Non-Smoker","Sunday","Dinner",2],
[9.68,1.32,"Male","Non-Smoker","Sunday","Dinner",2],
[30.4,5.6,"Male","Non-Smoker","Sunday","Dinner",4],
[18.29,3,"Male","Non-Smoker","Sunday","Dinner",2],
[22.23,5,"Male","Non-Smoker","Sunday","Dinner",2],
[32.4,6,"Male","Non-Smoker","Sunday","Dinner",4],
[28.55,2.05,"Male","Non-Smoker","Sunday","Dinner",3],
[18.04,3,"Male","Non-Smoker","Sunday","Dinner",2],
[12.54,2.5,"Male","Non-Smoker","Sunday","Dinner",2],
[10.29,2.6,"Female","Non-Smoker","Sunday","Dinner",2],
[34.81,5.2,"Female","Non-Smoker","Sunday","Dinner",4],
[9.94,1.56,"Male","Non-Smoker","Sunday","Dinner",2],
[25.56,4.34,"Male","Non-Smoker","Sunday","Dinner",4],
[19.49,3.51,"Male","Non-Smoker","Sunday","Dinner",2],
[38.01,3,"Male","Smoker","Saturday","Dinner",4],
[26.41,1.5,"Female","Non-Smoker","Saturday","Dinner",2],
[11.24,1.76,"Male","Smoker","Saturday","Dinner",2],
[48.27,6.73,"Male","Non-Smoker","Saturday","Dinner",4],
[20.29,3.21,"Male","Smoker","Saturday","Dinner",2],
[13.81,2,"Male","Smoker","Saturday","Dinner",2],
[11.02,1.98,"Male","Smoker","Saturday","Dinner",2],
[18.29,3.76,"Male","Smoker","Saturday","Dinner",4],
[17.59,2.64,"Male","Non-Smoker","Saturday","Dinner",3],
[20.08,3.15,"Male","Non-Smoker","Saturday","Dinner",3],
[16.45,2.47,"Female","Non-Smoker","Saturday","Dinner",2],
[3.07,1,"Female","Smoker","Saturday","Dinner",1],
[20.23,2.01,"Male","Non-Smoker","Saturday","Dinner",2],
[15.01,2.09,"Male","Smoker","Saturday","Dinner",2],
[12.02,1.97,"Male","Non-Smoker","Saturday","Dinner",2],
[17.07,3,"Female","Non-Smoker","Saturday","Dinner",3],
[26.86,3.14,"Female","Smoker","Saturday","Dinner",2],
[25.28,5,"Female","Smoker","Saturday","Dinner",2],
[14.73,2.2,"Female","Non-Smoker","Saturday","Dinner",2],
[10.51,1.25,"Male","Non-Smoker","Saturday","Dinner",2],
[17.92,3.08,"Male","Smoker","Saturday","Dinner",2],
[27.2,4,"Male","Non-Smoker","Thursday","Lunch",4],
[22.76,3,"Male","Non-Smoker","Thursday","Lunch",2],
[17.29,2.71,"Male","Non-Smoker","Thursday","Lunch",2],
[19.44,3,"Male","Smoker","Thursday","Lunch",2],
[16.66,3.4,"Male","Non-Smoker","Thursday","Lunch",2],
[10.07,1.83,"Female","Non-Smoker","Thursday","Lunch",1],
[32.68,5,"Male","Smoker","Thursday","Lunch",2],
[15.98,2.03,"Male","Non-Smoker","Thursday","Lunch",2],
[34.83,5.17,"Female","Non-Smoker","Thursday","Lunch",4],
[13.03,2,"Male","Non-Smoker","Thursday","Lunch",2],
[18.28,4,"Male","Non-Smoker","Thursday","Lunch",2],
[24.71,5.85,"Male","Non-Smoker","Thursday","Lunch",2],
[21.16,3,"Male","Non-Smoker","Thursday","Lunch",2],
[28.97,3,"Male","Smoker","Friday","Dinner",2],
[22.49,3.5,"Male","Non-Smoker","Friday","Dinner",2],
[5.75,1,"Female","Smoker","Friday","Dinner",2],
[16.32,4.3,"Female","Smoker","Friday","Dinner",2],
[22.75,3.25,"Female","Non-Smoker","Friday","Dinner",2],
[40.17,4.73,"Male","Smoker","Friday","Dinner",4],
[27.28,4,"Male","Smoker","Friday","Dinner",2],
[12.03,1.5,"Male","Smoker","Friday","Dinner",2],
[21.01,3,"Male","Smoker","Friday","Dinner",2],
[12.46,1.5,"Male","Non-Smoker","Friday","Dinner",2],
[11.35,2.5,"Female","Smoker","Friday","Dinner",2],
[15.38,3,"Female","Smoker","Friday","Dinner",2],
[44.3,2.5,"Female","Smoker","Saturday","Dinner",3],
[22.42,3.48,"Female","Smoker","Saturday","Dinner",2],
[20.92,4.08,"Female","Non-Smoker","Saturday","Dinner",2],
[15.36,1.64,"Male","Smoker","Saturday","Dinner",2],
[20.49,4.06,"Male","Smoker","Saturday","Dinner",2],
[25.21,4.29,"Male","Smoker","Saturday","Dinner",2],
[18.24,3.76,"Male","Non-Smoker","Saturday","Dinner",2],
[14.31,4,"Female","Smoker","Saturday","Dinner",2],
[14,3,"Male","Non-Smoker","Saturday","Dinner",2],
[7.25,1,"Female","Non-Smoker","Saturday","Dinner",1],
[38.07,4,"Male","Non-Smoker","Sunday","Dinner",3],
[23.95,2.55,"Male","Non-Smoker","Sunday","Dinner",2],
[25.71,4,"Female","Non-Smoker","Sunday","Dinner",3],
[17.31,3.5,"Female","Non-Smoker","Sunday","Dinner",2],
[29.93,5.07,"Male","Non-Smoker","Sunday","Dinner",4],
[10.65,1.5,"Female","Non-Smoker","Thursday","Lunch",2],
[12.43,1.8,"Female","Non-Smoker","Thursday","Lunch",2],
[24.08,2.92,"Female","Non-Smoker","Thursday","Lunch",4],
[11.69,2.31,"Male","Non-Smoker","Thursday","Lunch",2],
[13.42,1.68,"Female","Non-Smoker","Thursday","Lunch",2],
[14.26,2.5,"Male","Non-Smoker","Thursday","Lunch",2],
[15.95,2,"Male","Non-Smoker","Thursday","Lunch",2],
[12.48,2.52,"Female","Non-Smoker","Thursday","Lunch",2],
[29.8,4.2,"Female","Non-Smoker","Thursday","Lunch",6],
[8.52,1.48,"Male","Non-Smoker","Thursday","Lunch",2],
[14.52,2,"Female","Non-Smoker","Thursday","Lunch",2],
[11.38,2,"Female","Non-Smoker","Thursday","Lunch",2],
[22.82,2.18,"Male","Non-Smoker","Thursday","Lunch",3],
[19.08,1.5,"Male","Non-Smoker","Thursday","Lunch",2],
[20.27,2.83,"Female","Non-Smoker","Thursday","Lunch",2],
[11.17,1.5,"Female","Non-Smoker","Thursday","Lunch",2],
[12.26,2,"Female","Non-Smoker","Thursday","Lunch",2],
[18.26,3.25,"Female","Non-Smoker","Thursday","Lunch",2],
[8.51,1.25,"Female","Non-Smoker","Thursday","Lunch",2],
[10.33,2,"Female","Non-Smoker","Thursday","Lunch",2],
[14.15,2,"Female","Non-Smoker","Thursday","Lunch",2],
[16,2,"Male","Smoker","Thursday","Lunch",2],
[13.16,2.75,"Female","Non-Smoker","Thursday","Lunch",2],
[17.47,3.5,"Female","Non-Smoker","Thursday","Lunch",2],
[34.3,6.7,"Male","Non-Smoker","Thursday","Lunch",6],
[41.19,5,"Male","Non-Smoker","Thursday","Lunch",5],
[27.05,5,"Female","Non-Smoker","Thursday","Lunch",6],
[16.43,2.3,"Female","Non-Smoker","Thursday","Lunch",2],
[8.35,1.5,"Female","Non-Smoker","Thursday","Lunch",2],
[18.64,1.36,"Female","Non-Smoker","Thursday","Lunch",3],
[11.87,1.63,"Female","Non-Smoker","Thursday","Lunch",2],
[9.78,1.73,"Male","Non-Smoker","Thursday","Lunch",2],
[7.51,2,"Male","Non-Smoker","Thursday","Lunch",2],
[14.07,2.5,"Male","Non-Smoker","Sunday","Dinner",2],
[13.13,2,"Male","Non-Smoker","Sunday","Dinner",2],
[17.26,2.74,"Male","Non-Smoker","Sunday","Dinner",3],
[24.55,2,"Male","Non-Smoker","Sunday","Dinner",4],
[19.77,2,"Male","Non-Smoker","Sunday","Dinner",4],
[29.85,5.14,"Female","Non-Smoker","Sunday","Dinner",5],
[48.17,5,"Male","Non-Smoker","Sunday","Dinner",6],
[25,3.75,"Female","Non-Smoker","Sunday","Dinner",4],
[13.39,2.61,"Female","Non-Smoker","Sunday","Dinner",2],
[16.49,2,"Male","Non-Smoker","Sunday","Dinner",4],
[21.5,3.5,"Male","Non-Smoker","Sunday","Dinner",4],
[12.66,2.5,"Male","Non-Smoker","Sunday","Dinner",2],
[16.21,2,"Female","Non-Smoker","Sunday","Dinner",3],
[13.81,2,"Male","Non-Smoker","Sunday","Dinner",2],
[17.51,3,"Female","Smoker","Sunday","Dinner",2],
[24.52,3.48,"Male","Non-Smoker","Sunday","Dinner",3],
[20.76,2.24,"Male","Non-Smoker","Sunday","Dinner",2],
[31.71,4.5,"Male","Non-Smoker","Sunday","Dinner",4],
[10.59,1.61,"Female","Smoker","Saturday","Dinner",2],
[10.63,2,"Female","Smoker","Saturday","Dinner",2],
[50.81,10,"Male","Smoker","Saturday","Dinner",3],
[15.81,3.16,"Male","Smoker","Saturday","Dinner",2],
[7.25,5.15,"Male","Smoker","Sunday","Dinner",2],
[31.85,3.18,"Male","Smoker","Sunday","Dinner",2],
[16.82,4,"Male","Smoker","Sunday","Dinner",2],
[32.9,3.11,"Male","Smoker","Sunday","Dinner",2],
[17.89,2,"Male","Smoker","Sunday","Dinner",2],
[14.48,2,"Male","Smoker","Sunday","Dinner",2],
[9.6,4,"Female","Smoker","Sunday","Dinner",2],
[34.63,3.55,"Male","Smoker","Sunday","Dinner",2],
[34.65,3.68,"Male","Smoker","Sunday","Dinner",4],
[23.33,5.65,"Male","Smoker","Sunday","Dinner",2],
[45.35,3.5,"Male","Smoker","Sunday","Dinner",3],
[23.17,6.5,"Male","Smoker","Sunday","Dinner",4],
[40.55,3,"Male","Smoker","Sunday","Dinner",2],
[20.69,5,"Male","Non-Smoker","Sunday","Dinner",5],
[20.9,3.5,"Female","Smoker","Sunday","Dinner",3],
[30.46,2,"Male","Smoker","Sunday","Dinner",5],
[18.15,3.5,"Female","Smoker","Sunday","Dinner",3],
[23.1,4,"Male","Smoker","Sunday","Dinner",3],
[15.69,1.5,"Male","Smoker","Sunday","Dinner",2],
[19.81,4.19,"Female","Smoker","Thursday","Lunch",2],
[28.44,2.56,"Male","Smoker","Thursday","Lunch",2],
[15.48,2.02,"Male","Smoker","Thursday","Lunch",2],
[16.58,4,"Male","Smoker","Thursday","Lunch",2],
[7.56,1.44,"Male","Non-Smoker","Thursday","Lunch",2],
[10.34,2,"Male","Smoker","Thursday","Lunch",2],
[43.11,5,"Female","Smoker","Thursday","Lunch",4],
[13,2,"Female","Smoker","Thursday","Lunch",2],
[13.51,2,"Male","Smoker","Thursday","Lunch",2],
[18.71,4,"Male","Smoker","Thursday","Lunch",3],
[12.74,2.01,"Female","Smoker","Thursday","Lunch",2],
[13,2,"Female","Smoker","Thursday","Lunch",2],
[16.4,2.5,"Female","Smoker","Thursday","Lunch",2],
[20.53,4,"Male","Smoker","Thursday","Lunch",4],
[16.47,3.23,"Female","Smoker","Thursday","Lunch",3],
[26.59,3.41,"Male","Smoker","Saturday","Dinner",3],
[38.73,3,"Male","Smoker","Saturday","Dinner",4],
[24.27,2.03,"Male","Smoker","Saturday","Dinner",2],
[12.76,2.23,"Female","Smoker","Saturday","Dinner",2],
[30.06,2,"Male","Smoker","Saturday","Dinner",3],
[25.89,5.16,"Male","Smoker","Saturday","Dinner",4],
[48.33,9,"Male","Non-Smoker","Saturday","Dinner",4],
[13.27,2.5,"Female","Smoker","Saturday","Dinner",2],
[28.17,6.5,"Female","Smoker","Saturday","Dinner",3],
[12.9,1.1,"Female","Smoker","Saturday","Dinner",2],
[28.15,3,"Male","Smoker","Saturday","Dinner",5],
[11.59,1.5,"Male","Smoker","Saturday","Dinner",2],
[7.74,1.44,"Male","Smoker","Saturday","Dinner",2],
[30.14,3.09,"Female","Smoker","Saturday","Dinner",4],
[12.16,2.2,"Male","Smoker","Friday","Lunch",2],
[13.42,3.48,"Female","Smoker","Friday","Lunch",2],
[8.58,1.92,"Male","Smoker","Friday","Lunch",1],
[15.98,3,"Female","Non-Smoker","Friday","Lunch",3],
[13.42,1.58,"Male","Smoker","Friday","Lunch",2],
[16.27,2.5,"Female","Smoker","Friday","Lunch",2],
[10.09,2,"Female","Smoker","Friday","Lunch",2],
[20.45,3,"Male","Non-Smoker","Saturday","Dinner",4],
[13.28,2.72,"Male","Non-Smoker","Saturday","Dinner",2],
[22.12,2.88,"Female","Smoker","Saturday","Dinner",2],
[24.01,2,"Male","Smoker","Saturday","Dinner",4],
[15.69,3,"Male","Smoker","Saturday","Dinner",3],
[11.61,3.39,"Male","Non-Smoker","Saturday","Dinner",2],
[10.77,1.47,"Male","Non-Smoker","Saturday","Dinner",2],
[15.53,3,"Male","Smoker","Saturday","Dinner",2],
[10.07,1.25,"Male","Non-Smoker","Saturday","Dinner",2],
[12.6,1,"Male","Smoker","Saturday","Dinner",2],
[32.83,1.17,"Male","Smoker","Saturday","Dinner",2],
[35.83,4.67,"Female","Non-Smoker","Saturday","Dinner",3],
[29.03,5.92,"Male","Non-Smoker","Saturday","Dinner",3],
[27.18,2,"Female","Smoker","Saturday","Dinner",2],
[22.67,2,"Male","Smoker","Saturday","Dinner",2],
[17.82,1.75,"Male","Non-Smoker","Saturday","Dinner",2],
[18.78,3,"Female","Non-Smoker","Thursday","Dinner",2]
]

# %%
header = tips[0]
norm_tips = []
for i, row in enumerate(tips[1:]):
    skipped_attr = [4, 5]
    for j, attr in enumerate(row):
        if j not in skipped_attr:
            norm_tips.append([i % 55, row[4], row[5], header[j], attr])
            
norm_tips.sort(key=lambda x: x[0])
n = len(norm_tips)

# %%
norm_tips
# Out:
# [[0, 'Sunday', 'Dinner', 'Total Bill', 16.99],
#  [0, 'Sunday', 'Dinner', 'Tip', 1.01],
#  [0, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [0, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [0, 'Sunday', 'Dinner', 'Party Size', 2],
#  [0, 'Sunday', 'Dinner', 'Total Bill', 19.49],
#  [0, 'Sunday', 'Dinner', 'Tip', 3.51],
#  [0, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [0, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [0, 'Sunday', 'Dinner', 'Party Size', 2],
#  [0, 'Saturday', 'Dinner', 'Total Bill', 14],
#  [0, 'Saturday', 'Dinner', 'Tip', 3],
#  [0, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [0, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [0, 'Saturday', 'Dinner', 'Party Size', 2],
#  [0, 'Sunday', 'Dinner', 'Total Bill', 24.52],
#  [0, 'Sunday', 'Dinner', 'Tip', 3.48],
#  [0, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [0, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [0, 'Sunday', 'Dinner', 'Party Size', 3],
#  [0, 'Friday', 'Lunch', 'Total Bill', 12.16],
#  [0, 'Friday', 'Lunch', 'Tip', 2.2],
#  [0, 'Friday', 'Lunch', 'Payer Gender', 'Male'],
#  [0, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [0, 'Friday', 'Lunch', 'Party Size', 2],
#  [1, 'Sunday', 'Dinner', 'Total Bill', 10.34],
#  [1, 'Sunday', 'Dinner', 'Tip', 1.66],
#  [1, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [1, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [1, 'Sunday', 'Dinner', 'Party Size', 3],
#  [1, 'Saturday', 'Dinner', 'Total Bill', 38.01],
#  [1, 'Saturday', 'Dinner', 'Tip', 3],
#  [1, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [1, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [1, 'Saturday', 'Dinner', 'Party Size', 4],
#  [1, 'Saturday', 'Dinner', 'Total Bill', 7.25],
#  [1, 'Saturday', 'Dinner', 'Tip', 1],
#  [1, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [1, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [1, 'Saturday', 'Dinner', 'Party Size', 1],
#  [1, 'Sunday', 'Dinner', 'Total Bill', 20.76],
#  [1, 'Sunday', 'Dinner', 'Tip', 2.24],
#  [1, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [1, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [1, 'Sunday', 'Dinner', 'Party Size', 2],
#  [1, 'Friday', 'Lunch', 'Total Bill', 13.42],
#  [1, 'Friday', 'Lunch', 'Tip', 3.48],
#  [1, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
#  [1, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [1, 'Friday', 'Lunch', 'Party Size', 2],
#  [2, 'Sunday', 'Dinner', 'Total Bill', 21.01],
#  [2, 'Sunday', 'Dinner', 'Tip', 3.5],
#  [2, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [2, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [2, 'Sunday', 'Dinner', 'Party Size', 3],
#  [2, 'Saturday', 'Dinner', 'Total Bill', 26.41],
#  [2, 'Saturday', 'Dinner', 'Tip', 1.5],
#  [2, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [2, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [2, 'Saturday', 'Dinner', 'Party Size', 2],
#  [2, 'Sunday', 'Dinner', 'Total Bill', 38.07],
#  [2, 'Sunday', 'Dinner', 'Tip', 4],
#  [2, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [2, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [2, 'Sunday', 'Dinner', 'Party Size', 3],
#  [2, 'Sunday', 'Dinner', 'Total Bill', 31.71],
#  [2, 'Sunday', 'Dinner', 'Tip', 4.5],
#  [2, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [2, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [2, 'Sunday', 'Dinner', 'Party Size', 4],
#  [2, 'Friday', 'Lunch', 'Total Bill', 8.58],
#  [2, 'Friday', 'Lunch', 'Tip', 1.92],
#  [2, 'Friday', 'Lunch', 'Payer Gender', 'Male'],
#  [2, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [2, 'Friday', 'Lunch', 'Party Size', 1],
#  [3, 'Sunday', 'Dinner', 'Total Bill', 23.68],
#  [3, 'Sunday', 'Dinner', 'Tip', 3.31],
#  [3, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [3, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [3, 'Sunday', 'Dinner', 'Party Size', 2],
#  [3, 'Saturday', 'Dinner', 'Total Bill', 11.24],
#  [3, 'Saturday', 'Dinner', 'Tip', 1.76],
#  [3, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [3, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [3, 'Saturday', 'Dinner', 'Party Size', 2],
#  [3, 'Sunday', 'Dinner', 'Total Bill', 23.95],
#  [3, 'Sunday', 'Dinner', 'Tip', 2.55],
#  [3, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [3, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [3, 'Sunday', 'Dinner', 'Party Size', 2],
#  [3, 'Saturday', 'Dinner', 'Total Bill', 10.59],
#  [3, 'Saturday', 'Dinner', 'Tip', 1.61],
#  [3, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [3, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [3, 'Saturday', 'Dinner', 'Party Size', 2],
#  [3, 'Friday', 'Lunch', 'Total Bill', 15.98],
#  [3, 'Friday', 'Lunch', 'Tip', 3],
#  [3, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
#  [3, 'Friday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [3, 'Friday', 'Lunch', 'Party Size', 3],
#  [4, 'Sunday', 'Dinner', 'Total Bill', 24.59],
#  [4, 'Sunday', 'Dinner', 'Tip', 3.61],
#  [4, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [4, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [4, 'Sunday', 'Dinner', 'Party Size', 4],
#  [4, 'Saturday', 'Dinner', 'Total Bill', 48.27],
#  [4, 'Saturday', 'Dinner', 'Tip', 6.73],
#  [4, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [4, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [4, 'Saturday', 'Dinner', 'Party Size', 4],
#  [4, 'Sunday', 'Dinner', 'Total Bill', 25.71],
#  [4, 'Sunday', 'Dinner', 'Tip', 4],
#  [4, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [4, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [4, 'Sunday', 'Dinner', 'Party Size', 3],
#  [4, 'Saturday', 'Dinner', 'Total Bill', 10.63],
#  [4, 'Saturday', 'Dinner', 'Tip', 2],
#  [4, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [4, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [4, 'Saturday', 'Dinner', 'Party Size', 2],
#  [4, 'Friday', 'Lunch', 'Total Bill', 13.42],
#  [4, 'Friday', 'Lunch', 'Tip', 1.58],
#  [4, 'Friday', 'Lunch', 'Payer Gender', 'Male'],
#  [4, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [4, 'Friday', 'Lunch', 'Party Size', 2],
#  [5, 'Sunday', 'Dinner', 'Total Bill', 25.29],
#  [5, 'Sunday', 'Dinner', 'Tip', 4.71],
#  [5, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [5, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [5, 'Sunday', 'Dinner', 'Party Size', 4],
#  [5, 'Saturday', 'Dinner', 'Total Bill', 20.29],
#  [5, 'Saturday', 'Dinner', 'Tip', 3.21],
#  [5, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [5, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [5, 'Saturday', 'Dinner', 'Party Size', 2],
#  [5, 'Sunday', 'Dinner', 'Total Bill', 17.31],
#  [5, 'Sunday', 'Dinner', 'Tip', 3.5],
#  [5, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [5, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [5, 'Sunday', 'Dinner', 'Party Size', 2],
#  [5, 'Saturday', 'Dinner', 'Total Bill', 50.81],
#  [5, 'Saturday', 'Dinner', 'Tip', 10],
#  [5, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [5, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [5, 'Saturday', 'Dinner', 'Party Size', 3],
#  [5, 'Friday', 'Lunch', 'Total Bill', 16.27],
#  [5, 'Friday', 'Lunch', 'Tip', 2.5],
#  [5, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
#  [5, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [5, 'Friday', 'Lunch', 'Party Size', 2],
#  [6, 'Sunday', 'Dinner', 'Total Bill', 8.77],
#  [6, 'Sunday', 'Dinner', 'Tip', 2],
#  [6, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [6, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [6, 'Sunday', 'Dinner', 'Party Size', 2],
#  [6, 'Saturday', 'Dinner', 'Total Bill', 13.81],
#  [6, 'Saturday', 'Dinner', 'Tip', 2],
#  [6, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [6, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [6, 'Saturday', 'Dinner', 'Party Size', 2],
#  [6, 'Sunday', 'Dinner', 'Total Bill', 29.93],
#  [6, 'Sunday', 'Dinner', 'Tip', 5.07],
#  [6, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [6, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [6, 'Sunday', 'Dinner', 'Party Size', 4],
#  [6, 'Saturday', 'Dinner', 'Total Bill', 15.81],
#  [6, 'Saturday', 'Dinner', 'Tip', 3.16],
#  [6, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [6, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [6, 'Saturday', 'Dinner', 'Party Size', 2],
#  [6, 'Friday', 'Lunch', 'Total Bill', 10.09],
#  [6, 'Friday', 'Lunch', 'Tip', 2],
#  [6, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
#  [6, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [6, 'Friday', 'Lunch', 'Party Size', 2],
#  [7, 'Sunday', 'Dinner', 'Total Bill', 26.88],
#  [7, 'Sunday', 'Dinner', 'Tip', 3.12],
#  [7, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [7, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [7, 'Sunday', 'Dinner', 'Party Size', 4],
#  [7, 'Saturday', 'Dinner', 'Total Bill', 11.02],
#  [7, 'Saturday', 'Dinner', 'Tip', 1.98],
#  [7, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [7, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [7, 'Saturday', 'Dinner', 'Party Size', 2],
#  [7, 'Thursday', 'Lunch', 'Total Bill', 10.65],
#  [7, 'Thursday', 'Lunch', 'Tip', 1.5],
#  [7, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [7, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [7, 'Thursday', 'Lunch', 'Party Size', 2],
#  [7, 'Sunday', 'Dinner', 'Total Bill', 7.25],
#  [7, 'Sunday', 'Dinner', 'Tip', 5.15],
#  [7, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [7, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [7, 'Sunday', 'Dinner', 'Party Size', 2],
#  [7, 'Saturday', 'Dinner', 'Total Bill', 20.45],
#  [7, 'Saturday', 'Dinner', 'Tip', 3],
#  [7, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [7, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [7, 'Saturday', 'Dinner', 'Party Size', 4],
#  [8, 'Sunday', 'Dinner', 'Total Bill', 15.04],
#  [8, 'Sunday', 'Dinner', 'Tip', 1.96],
#  [8, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [8, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [8, 'Sunday', 'Dinner', 'Party Size', 2],
#  [8, 'Saturday', 'Dinner', 'Total Bill', 18.29],
#  [8, 'Saturday', 'Dinner', 'Tip', 3.76],
#  [8, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [8, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [8, 'Saturday', 'Dinner', 'Party Size', 4],
#  [8, 'Thursday', 'Lunch', 'Total Bill', 12.43],
#  [8, 'Thursday', 'Lunch', 'Tip', 1.8],
#  [8, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [8, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [8, 'Thursday', 'Lunch', 'Party Size', 2],
#  [8, 'Sunday', 'Dinner', 'Total Bill', 31.85],
#  [8, 'Sunday', 'Dinner', 'Tip', 3.18],
#  [8, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [8, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [8, 'Sunday', 'Dinner', 'Party Size', 2],
#  [8, 'Saturday', 'Dinner', 'Total Bill', 13.28],
#  [8, 'Saturday', 'Dinner', 'Tip', 2.72],
#  [8, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [8, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [8, 'Saturday', 'Dinner', 'Party Size', 2],
#  [9, 'Sunday', 'Dinner', 'Total Bill', 14.78],
#  [9, 'Sunday', 'Dinner', 'Tip', 3.23],
#  [9, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [9, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [9, 'Sunday', 'Dinner', 'Party Size', 2],
#  [9, 'Saturday', 'Dinner', 'Total Bill', 17.59],
#  [9, 'Saturday', 'Dinner', 'Tip', 2.64],
#  [9, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [9, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [9, 'Saturday', 'Dinner', 'Party Size', 3],
#  [9, 'Thursday', 'Lunch', 'Total Bill', 24.08],
#  [9, 'Thursday', 'Lunch', 'Tip', 2.92],
#  [9, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [9, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [9, 'Thursday', 'Lunch', 'Party Size', 4],
#  [9, 'Sunday', 'Dinner', 'Total Bill', 16.82],
#  [9, 'Sunday', 'Dinner', 'Tip', 4],
#  [9, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [9, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [9, 'Sunday', 'Dinner', 'Party Size', 2],
#  [9, 'Saturday', 'Dinner', 'Total Bill', 22.12],
#  [9, 'Saturday', 'Dinner', 'Tip', 2.88],
#  [9, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [9, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [9, 'Saturday', 'Dinner', 'Party Size', 2],
#  [10, 'Sunday', 'Dinner', 'Total Bill', 10.27],
#  [10, 'Sunday', 'Dinner', 'Tip', 1.71],
#  [10, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [10, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [10, 'Sunday', 'Dinner', 'Party Size', 2],
#  [10, 'Saturday', 'Dinner', 'Total Bill', 20.08],
#  [10, 'Saturday', 'Dinner', 'Tip', 3.15],
#  [10, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [10, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [10, 'Saturday', 'Dinner', 'Party Size', 3],
#  [10, 'Thursday', 'Lunch', 'Total Bill', 11.69],
#  [10, 'Thursday', 'Lunch', 'Tip', 2.31],
#  [10, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [10, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [10, 'Thursday', 'Lunch', 'Party Size', 2],
#  [10, 'Sunday', 'Dinner', 'Total Bill', 32.9],
#  [10, 'Sunday', 'Dinner', 'Tip', 3.11],
#  [10, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [10, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [10, 'Sunday', 'Dinner', 'Party Size', 2],
#  [10, 'Saturday', 'Dinner', 'Total Bill', 24.01],
#  [10, 'Saturday', 'Dinner', 'Tip', 2],
#  [10, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [10, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [10, 'Saturday', 'Dinner', 'Party Size', 4],
#  [11, 'Sunday', 'Dinner', 'Total Bill', 35.26],
#  [11, 'Sunday', 'Dinner', 'Tip', 5],
#  [11, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [11, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [11, 'Sunday', 'Dinner', 'Party Size', 4],
#  [11, 'Saturday', 'Dinner', 'Total Bill', 16.45],
#  [11, 'Saturday', 'Dinner', 'Tip', 2.47],
#  [11, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [11, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [11, 'Saturday', 'Dinner', 'Party Size', 2],
#  [11, 'Thursday', 'Lunch', 'Total Bill', 13.42],
#  [11, 'Thursday', 'Lunch', 'Tip', 1.68],
#  [11, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [11, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [11, 'Thursday', 'Lunch', 'Party Size', 2],
#  [11, 'Sunday', 'Dinner', 'Total Bill', 17.89],
#  [11, 'Sunday', 'Dinner', 'Tip', 2],
#  [11, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [11, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [11, 'Sunday', 'Dinner', 'Party Size', 2],
#  [11, 'Saturday', 'Dinner', 'Total Bill', 15.69],
#  [11, 'Saturday', 'Dinner', 'Tip', 3],
#  [11, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [11, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [11, 'Saturday', 'Dinner', 'Party Size', 3],
#  [12, 'Sunday', 'Dinner', 'Total Bill', 15.42],
#  [12, 'Sunday', 'Dinner', 'Tip', 1.57],
#  [12, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [12, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [12, 'Sunday', 'Dinner', 'Party Size', 2],
#  [12, 'Saturday', 'Dinner', 'Total Bill', 3.07],
#  [12, 'Saturday', 'Dinner', 'Tip', 1],
#  [12, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [12, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [12, 'Saturday', 'Dinner', 'Party Size', 1],
#  [12, 'Thursday', 'Lunch', 'Total Bill', 14.26],
#  [12, 'Thursday', 'Lunch', 'Tip', 2.5],
#  [12, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [12, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [12, 'Thursday', 'Lunch', 'Party Size', 2],
#  [12, 'Sunday', 'Dinner', 'Total Bill', 14.48],
#  [12, 'Sunday', 'Dinner', 'Tip', 2],
#  [12, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [12, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [12, 'Sunday', 'Dinner', 'Party Size', 2],
#  [12, 'Saturday', 'Dinner', 'Total Bill', 11.61],
#  [12, 'Saturday', 'Dinner', 'Tip', 3.39],
#  [12, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [12, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [12, 'Saturday', 'Dinner', 'Party Size', 2],
#  [13, 'Sunday', 'Dinner', 'Total Bill', 18.43],
#  [13, 'Sunday', 'Dinner', 'Tip', 3],
#  [13, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [13, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [13, 'Sunday', 'Dinner', 'Party Size', 4],
#  [13, 'Saturday', 'Dinner', 'Total Bill', 20.23],
#  [13, 'Saturday', 'Dinner', 'Tip', 2.01],
#  [13, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [13, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [13, 'Saturday', 'Dinner', 'Party Size', 2],
#  [13, 'Thursday', 'Lunch', 'Total Bill', 15.95],
#  [13, 'Thursday', 'Lunch', 'Tip', 2],
#  [13, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [13, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [13, 'Thursday', 'Lunch', 'Party Size', 2],
#  [13, 'Sunday', 'Dinner', 'Total Bill', 9.6],
#  [13, 'Sunday', 'Dinner', 'Tip', 4],
#  [13, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [13, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [13, 'Sunday', 'Dinner', 'Party Size', 2],
#  [13, 'Saturday', 'Dinner', 'Total Bill', 10.77],
#  [13, 'Saturday', 'Dinner', 'Tip', 1.47],
#  [13, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [13, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [13, 'Saturday', 'Dinner', 'Party Size', 2],
#  [14, 'Sunday', 'Dinner', 'Total Bill', 14.83],
#  [14, 'Sunday', 'Dinner', 'Tip', 3.02],
#  [14, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [14, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [14, 'Sunday', 'Dinner', 'Party Size', 2],
#  [14, 'Saturday', 'Dinner', 'Total Bill', 15.01],
#  [14, 'Saturday', 'Dinner', 'Tip', 2.09],
#  [14, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [14, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [14, 'Saturday', 'Dinner', 'Party Size', 2],
#  [14, 'Thursday', 'Lunch', 'Total Bill', 12.48],
#  [14, 'Thursday', 'Lunch', 'Tip', 2.52],
#  [14, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [14, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [14, 'Thursday', 'Lunch', 'Party Size', 2],
#  [14, 'Sunday', 'Dinner', 'Total Bill', 34.63],
#  [14, 'Sunday', 'Dinner', 'Tip', 3.55],
#  [14, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [14, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [14, 'Sunday', 'Dinner', 'Party Size', 2],
#  [14, 'Saturday', 'Dinner', 'Total Bill', 15.53],
#  [14, 'Saturday', 'Dinner', 'Tip', 3],
#  [14, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [14, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [14, 'Saturday', 'Dinner', 'Party Size', 2],
#  [15, 'Sunday', 'Dinner', 'Total Bill', 21.58],
#  [15, 'Sunday', 'Dinner', 'Tip', 3.92],
#  [15, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [15, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [15, 'Sunday', 'Dinner', 'Party Size', 2],
#  [15, 'Saturday', 'Dinner', 'Total Bill', 12.02],
#  [15, 'Saturday', 'Dinner', 'Tip', 1.97],
#  [15, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [15, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [15, 'Saturday', 'Dinner', 'Party Size', 2],
#  [15, 'Thursday', 'Lunch', 'Total Bill', 29.8],
#  [15, 'Thursday', 'Lunch', 'Tip', 4.2],
#  [15, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [15, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [15, 'Thursday', 'Lunch', 'Party Size', 6],
#  [15, 'Sunday', 'Dinner', 'Total Bill', 34.65],
#  [15, 'Sunday', 'Dinner', 'Tip', 3.68],
#  [15, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [15, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [15, 'Sunday', 'Dinner', 'Party Size', 4],
#  [15, 'Saturday', 'Dinner', 'Total Bill', 10.07],
#  [15, 'Saturday', 'Dinner', 'Tip', 1.25],
#  [15, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [15, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [15, 'Saturday', 'Dinner', 'Party Size', 2],
#  [16, 'Sunday', 'Dinner', 'Total Bill', 10.33],
#  [16, 'Sunday', 'Dinner', 'Tip', 1.67],
#  [16, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [16, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [16, 'Sunday', 'Dinner', 'Party Size', 3],
#  [16, 'Saturday', 'Dinner', 'Total Bill', 17.07],
#  [16, 'Saturday', 'Dinner', 'Tip', 3],
#  [16, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [16, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [16, 'Saturday', 'Dinner', 'Party Size', 3],
#  [16, 'Thursday', 'Lunch', 'Total Bill', 8.52],
#  [16, 'Thursday', 'Lunch', 'Tip', 1.48],
#  [16, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [16, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [16, 'Thursday', 'Lunch', 'Party Size', 2],
#  [16, 'Sunday', 'Dinner', 'Total Bill', 23.33],
#  [16, 'Sunday', 'Dinner', 'Tip', 5.65],
#  [16, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [16, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [16, 'Sunday', 'Dinner', 'Party Size', 2],
#  [16, 'Saturday', 'Dinner', 'Total Bill', 12.6],
#  [16, 'Saturday', 'Dinner', 'Tip', 1],
#  [16, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [16, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [16, 'Saturday', 'Dinner', 'Party Size', 2],
#  [17, 'Sunday', 'Dinner', 'Total Bill', 16.29],
#  [17, 'Sunday', 'Dinner', 'Tip', 3.71],
#  [17, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [17, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [17, 'Sunday', 'Dinner', 'Party Size', 3],
#  [17, 'Saturday', 'Dinner', 'Total Bill', 26.86],
#  [17, 'Saturday', 'Dinner', 'Tip', 3.14],
#  [17, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [17, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [17, 'Saturday', 'Dinner', 'Party Size', 2],
#  [17, 'Thursday', 'Lunch', 'Total Bill', 14.52],
#  [17, 'Thursday', 'Lunch', 'Tip', 2],
#  [17, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [17, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [17, 'Thursday', 'Lunch', 'Party Size', 2],
#  [17, 'Sunday', 'Dinner', 'Total Bill', 45.35],
#  [17, 'Sunday', 'Dinner', 'Tip', 3.5],
#  [17, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [17, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [17, 'Sunday', 'Dinner', 'Party Size', 3],
#  [17, 'Saturday', 'Dinner', 'Total Bill', 32.83],
#  [17, 'Saturday', 'Dinner', 'Tip', 1.17],
#  [17, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [17, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [17, 'Saturday', 'Dinner', 'Party Size', 2],
#  [18, 'Sunday', 'Dinner', 'Total Bill', 16.97],
#  [18, 'Sunday', 'Dinner', 'Tip', 3.5],
#  [18, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [18, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [18, 'Sunday', 'Dinner', 'Party Size', 3],
#  [18, 'Saturday', 'Dinner', 'Total Bill', 25.28],
#  [18, 'Saturday', 'Dinner', 'Tip', 5],
#  [18, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [18, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [18, 'Saturday', 'Dinner', 'Party Size', 2],
#  [18, 'Thursday', 'Lunch', 'Total Bill', 11.38],
#  [18, 'Thursday', 'Lunch', 'Tip', 2],
#  [18, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [18, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [18, 'Thursday', 'Lunch', 'Party Size', 2],
#  [18, 'Sunday', 'Dinner', 'Total Bill', 23.17],
#  [18, 'Sunday', 'Dinner', 'Tip', 6.5],
#  [18, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [18, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [18, 'Sunday', 'Dinner', 'Party Size', 4],
#  [18, 'Saturday', 'Dinner', 'Total Bill', 35.83],
#  [18, 'Saturday', 'Dinner', 'Tip', 4.67],
#  [18, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [18, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [18, 'Saturday', 'Dinner', 'Party Size', 3],
#  [19, 'Saturday', 'Dinner', 'Total Bill', 20.65],
#  [19, 'Saturday', 'Dinner', 'Tip', 3.35],
#  [19, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [19, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [19, 'Saturday', 'Dinner', 'Party Size', 3],
#  [19, 'Saturday', 'Dinner', 'Total Bill', 14.73],
#  [19, 'Saturday', 'Dinner', 'Tip', 2.2],
#  [19, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [19, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [19, 'Saturday', 'Dinner', 'Party Size', 2],
#  [19, 'Thursday', 'Lunch', 'Total Bill', 22.82],
#  [19, 'Thursday', 'Lunch', 'Tip', 2.18],
#  [19, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [19, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [19, 'Thursday', 'Lunch', 'Party Size', 3],
#  [19, 'Sunday', 'Dinner', 'Total Bill', 40.55],
#  [19, 'Sunday', 'Dinner', 'Tip', 3],
#  [19, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [19, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [19, 'Sunday', 'Dinner', 'Party Size', 2],
#  [19, 'Saturday', 'Dinner', 'Total Bill', 29.03],
#  [19, 'Saturday', 'Dinner', 'Tip', 5.92],
#  [19, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [19, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [19, 'Saturday', 'Dinner', 'Party Size', 3],
#  [20, 'Saturday', 'Dinner', 'Total Bill', 17.92],
#  [20, 'Saturday', 'Dinner', 'Tip', 4.08],
#  [20, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [20, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [20, 'Saturday', 'Dinner', 'Party Size', 2],
#  [20, 'Saturday', 'Dinner', 'Total Bill', 10.51],
#  [20, 'Saturday', 'Dinner', 'Tip', 1.25],
#  [20, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [20, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [20, 'Saturday', 'Dinner', 'Party Size', 2],
#  [20, 'Thursday', 'Lunch', 'Total Bill', 19.08],
#  [20, 'Thursday', 'Lunch', 'Tip', 1.5],
#  [20, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [20, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [20, 'Thursday', 'Lunch', 'Party Size', 2],
#  [20, 'Sunday', 'Dinner', 'Total Bill', 20.69],
#  [20, 'Sunday', 'Dinner', 'Tip', 5],
#  [20, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [20, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [20, 'Sunday', 'Dinner', 'Party Size', 5],
#  [20, 'Saturday', 'Dinner', 'Total Bill', 27.18],
#  [20, 'Saturday', 'Dinner', 'Tip', 2],
#  [20, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [20, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [20, 'Saturday', 'Dinner', 'Party Size', 2],
#  [21, 'Saturday', 'Dinner', 'Total Bill', 20.29],
#  [21, 'Saturday', 'Dinner', 'Tip', 2.75],
#  [21, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [21, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [21, 'Saturday', 'Dinner', 'Party Size', 2],
#  [21, 'Saturday', 'Dinner', 'Total Bill', 17.92],
#  [21, 'Saturday', 'Dinner', 'Tip', 3.08],
#  [21, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [21, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [21, 'Saturday', 'Dinner', 'Party Size', 2],
#  [21, 'Thursday', 'Lunch', 'Total Bill', 20.27],
#  [21, 'Thursday', 'Lunch', 'Tip', 2.83],
#  [21, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [21, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [21, 'Thursday', 'Lunch', 'Party Size', 2],
#  [21, 'Sunday', 'Dinner', 'Total Bill', 20.9],
#  [21, 'Sunday', 'Dinner', 'Tip', 3.5],
#  [21, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [21, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [21, 'Sunday', 'Dinner', 'Party Size', 3],
#  [21, 'Saturday', 'Dinner', 'Total Bill', 22.67],
#  [21, 'Saturday', 'Dinner', 'Tip', 2],
#  [21, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [21, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [21, 'Saturday', 'Dinner', 'Party Size', 2],
#  [22, 'Saturday', 'Dinner', 'Total Bill', 15.77],
#  [22, 'Saturday', 'Dinner', 'Tip', 2.23],
#  [22, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [22, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [22, 'Saturday', 'Dinner', 'Party Size', 2],
#  [22, 'Thursday', 'Lunch', 'Total Bill', 27.2],
#  [22, 'Thursday', 'Lunch', 'Tip', 4],
#  [22, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [22, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [22, 'Thursday', 'Lunch', 'Party Size', 4],
#  [22, 'Thursday', 'Lunch', 'Total Bill', 11.17],
#  [22, 'Thursday', 'Lunch', 'Tip', 1.5],
#  [22, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [22, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [22, 'Thursday', 'Lunch', 'Party Size', 2],
#  [22, 'Sunday', 'Dinner', 'Total Bill', 30.46],
#  [22, 'Sunday', 'Dinner', 'Tip', 2],
#  [22, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [22, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [22, 'Sunday', 'Dinner', 'Party Size', 5],
#  [22, 'Saturday', 'Dinner', 'Total Bill', 17.82],
#  [22, 'Saturday', 'Dinner', 'Tip', 1.75],
#  [22, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [22, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [22, 'Saturday', 'Dinner', 'Party Size', 2],
#  [23, 'Saturday', 'Dinner', 'Total Bill', 39.42],
#  [23, 'Saturday', 'Dinner', 'Tip', 7.58],
#  [23, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [23, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [23, 'Saturday', 'Dinner', 'Party Size', 4],
#  [23, 'Thursday', 'Lunch', 'Total Bill', 22.76],
#  [23, 'Thursday', 'Lunch', 'Tip', 3],
#  [23, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [23, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [23, 'Thursday', 'Lunch', 'Party Size', 2],
#  [23, 'Thursday', 'Lunch', 'Total Bill', 12.26],
#  [23, 'Thursday', 'Lunch', 'Tip', 2],
#  [23, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [23, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [23, 'Thursday', 'Lunch', 'Party Size', 2],
#  [23, 'Sunday', 'Dinner', 'Total Bill', 18.15],
#  [23, 'Sunday', 'Dinner', 'Tip', 3.5],
#  [23, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
#  [23, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [23, 'Sunday', 'Dinner', 'Party Size', 3],
#  [23, 'Thursday', 'Dinner', 'Total Bill', 18.78],
#  [23, 'Thursday', 'Dinner', 'Tip', 3],
#  [23, 'Thursday', 'Dinner', 'Payer Gender', 'Female'],
#  [23, 'Thursday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [23, 'Thursday', 'Dinner', 'Party Size', 2],
#  [24, 'Saturday', 'Dinner', 'Total Bill', 19.82],
#  [24, 'Saturday', 'Dinner', 'Tip', 3.18],
#  [24, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [24, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [24, 'Saturday', 'Dinner', 'Party Size', 2],
#  [24, 'Thursday', 'Lunch', 'Total Bill', 17.29],
#  [24, 'Thursday', 'Lunch', 'Tip', 2.71],
#  [24, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [24, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [24, 'Thursday', 'Lunch', 'Party Size', 2],
#  [24, 'Thursday', 'Lunch', 'Total Bill', 18.26],
#  [24, 'Thursday', 'Lunch', 'Tip', 3.25],
#  [24, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [24, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [24, 'Thursday', 'Lunch', 'Party Size', 2],
#  [24, 'Sunday', 'Dinner', 'Total Bill', 23.1],
#  [24, 'Sunday', 'Dinner', 'Tip', 4],
#  [24, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [24, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [24, 'Sunday', 'Dinner', 'Party Size', 3],
#  [25, 'Saturday', 'Dinner', 'Total Bill', 17.81],
#  [25, 'Saturday', 'Dinner', 'Tip', 2.34],
#  [25, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [25, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [25, 'Saturday', 'Dinner', 'Party Size', 4],
#  [25, 'Thursday', 'Lunch', 'Total Bill', 19.44],
#  [25, 'Thursday', 'Lunch', 'Tip', 3],
#  [25, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [25, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [25, 'Thursday', 'Lunch', 'Party Size', 2],
#  [25, 'Thursday', 'Lunch', 'Total Bill', 8.51],
#  [25, 'Thursday', 'Lunch', 'Tip', 1.25],
#  [25, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [25, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [25, 'Thursday', 'Lunch', 'Party Size', 2],
#  [25, 'Sunday', 'Dinner', 'Total Bill', 15.69],
#  [25, 'Sunday', 'Dinner', 'Tip', 1.5],
#  [25, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [25, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [25, 'Sunday', 'Dinner', 'Party Size', 2],
#  [26, 'Saturday', 'Dinner', 'Total Bill', 13.37],
#  [26, 'Saturday', 'Dinner', 'Tip', 2],
#  [26, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [26, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [26, 'Saturday', 'Dinner', 'Party Size', 2],
#  [26, 'Thursday', 'Lunch', 'Total Bill', 16.66],
#  [26, 'Thursday', 'Lunch', 'Tip', 3.4],
#  [26, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [26, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [26, 'Thursday', 'Lunch', 'Party Size', 2],
#  [26, 'Thursday', 'Lunch', 'Total Bill', 10.33],
#  [26, 'Thursday', 'Lunch', 'Tip', 2],
#  [26, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [26, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [26, 'Thursday', 'Lunch', 'Party Size', 2],
#  [26, 'Thursday', 'Lunch', 'Total Bill', 19.81],
#  [26, 'Thursday', 'Lunch', 'Tip', 4.19],
#  [26, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [26, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [26, 'Thursday', 'Lunch', 'Party Size', 2],
#  [27, 'Saturday', 'Dinner', 'Total Bill', 12.69],
#  [27, 'Saturday', 'Dinner', 'Tip', 2],
#  [27, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [27, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [27, 'Saturday', 'Dinner', 'Party Size', 2],
#  [27, 'Thursday', 'Lunch', 'Total Bill', 10.07],
#  [27, 'Thursday', 'Lunch', 'Tip', 1.83],
#  [27, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [27, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [27, 'Thursday', 'Lunch', 'Party Size', 1],
#  [27, 'Thursday', 'Lunch', 'Total Bill', 14.15],
#  [27, 'Thursday', 'Lunch', 'Tip', 2],
#  [27, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [27, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [27, 'Thursday', 'Lunch', 'Party Size', 2],
#  [27, 'Thursday', 'Lunch', 'Total Bill', 28.44],
#  [27, 'Thursday', 'Lunch', 'Tip', 2.56],
#  [27, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [27, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [27, 'Thursday', 'Lunch', 'Party Size', 2],
#  [28, 'Saturday', 'Dinner', 'Total Bill', 21.7],
#  [28, 'Saturday', 'Dinner', 'Tip', 4.3],
#  [28, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [28, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [28, 'Saturday', 'Dinner', 'Party Size', 2],
#  [28, 'Thursday', 'Lunch', 'Total Bill', 32.68],
#  [28, 'Thursday', 'Lunch', 'Tip', 5],
#  [28, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [28, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [28, 'Thursday', 'Lunch', 'Party Size', 2],
#  [28, 'Thursday', 'Lunch', 'Total Bill', 16],
#  [28, 'Thursday', 'Lunch', 'Tip', 2],
#  [28, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [28, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [28, 'Thursday', 'Lunch', 'Party Size', 2],
#  [28, 'Thursday', 'Lunch', 'Total Bill', 15.48],
#  [28, 'Thursday', 'Lunch', 'Tip', 2.02],
#  [28, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [28, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [28, 'Thursday', 'Lunch', 'Party Size', 2],
#  [29, 'Saturday', 'Dinner', 'Total Bill', 19.65],
#  [29, 'Saturday', 'Dinner', 'Tip', 3],
#  [29, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [29, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [29, 'Saturday', 'Dinner', 'Party Size', 2],
#  [29, 'Thursday', 'Lunch', 'Total Bill', 15.98],
#  [29, 'Thursday', 'Lunch', 'Tip', 2.03],
#  [29, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [29, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [29, 'Thursday', 'Lunch', 'Party Size', 2],
#  [29, 'Thursday', 'Lunch', 'Total Bill', 13.16],
#  [29, 'Thursday', 'Lunch', 'Tip', 2.75],
#  [29, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [29, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [29, 'Thursday', 'Lunch', 'Party Size', 2],
#  [29, 'Thursday', 'Lunch', 'Total Bill', 16.58],
#  [29, 'Thursday', 'Lunch', 'Tip', 4],
#  [29, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [29, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [29, 'Thursday', 'Lunch', 'Party Size', 2],
#  [30, 'Saturday', 'Dinner', 'Total Bill', 9.55],
#  [30, 'Saturday', 'Dinner', 'Tip', 1.45],
#  [30, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [30, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [30, 'Saturday', 'Dinner', 'Party Size', 2],
#  [30, 'Thursday', 'Lunch', 'Total Bill', 34.83],
#  [30, 'Thursday', 'Lunch', 'Tip', 5.17],
#  [30, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [30, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [30, 'Thursday', 'Lunch', 'Party Size', 4],
#  [30, 'Thursday', 'Lunch', 'Total Bill', 17.47],
#  [30, 'Thursday', 'Lunch', 'Tip', 3.5],
#  [30, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [30, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [30, 'Thursday', 'Lunch', 'Party Size', 2],
#  [30, 'Thursday', 'Lunch', 'Total Bill', 7.56],
#  [30, 'Thursday', 'Lunch', 'Tip', 1.44],
#  [30, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [30, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [30, 'Thursday', 'Lunch', 'Party Size', 2],
#  [31, 'Saturday', 'Dinner', 'Total Bill', 18.35],
#  [31, 'Saturday', 'Dinner', 'Tip', 2.5],
#  [31, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [31, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [31, 'Saturday', 'Dinner', 'Party Size', 4],
#  [31, 'Thursday', 'Lunch', 'Total Bill', 13.03],
#  [31, 'Thursday', 'Lunch', 'Tip', 2],
#  [31, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [31, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [31, 'Thursday', 'Lunch', 'Party Size', 2],
#  [31, 'Thursday', 'Lunch', 'Total Bill', 34.3],
#  [31, 'Thursday', 'Lunch', 'Tip', 6.7],
#  [31, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [31, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [31, 'Thursday', 'Lunch', 'Party Size', 6],
#  [31, 'Thursday', 'Lunch', 'Total Bill', 10.34],
#  [31, 'Thursday', 'Lunch', 'Tip', 2],
#  [31, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [31, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [31, 'Thursday', 'Lunch', 'Party Size', 2],
#  [32, 'Saturday', 'Dinner', 'Total Bill', 15.06],
#  [32, 'Saturday', 'Dinner', 'Tip', 3],
#  [32, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [32, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [32, 'Saturday', 'Dinner', 'Party Size', 2],
#  [32, 'Thursday', 'Lunch', 'Total Bill', 18.28],
#  [32, 'Thursday', 'Lunch', 'Tip', 4],
#  [32, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [32, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [32, 'Thursday', 'Lunch', 'Party Size', 2],
#  [32, 'Thursday', 'Lunch', 'Total Bill', 41.19],
#  [32, 'Thursday', 'Lunch', 'Tip', 5],
#  [32, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [32, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [32, 'Thursday', 'Lunch', 'Party Size', 5],
#  [32, 'Thursday', 'Lunch', 'Total Bill', 43.11],
#  [32, 'Thursday', 'Lunch', 'Tip', 5],
#  [32, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [32, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [32, 'Thursday', 'Lunch', 'Party Size', 4],
#  [33, 'Saturday', 'Dinner', 'Total Bill', 20.69],
#  [33, 'Saturday', 'Dinner', 'Tip', 2.45],
#  [33, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [33, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [33, 'Saturday', 'Dinner', 'Party Size', 4],
#  [33, 'Thursday', 'Lunch', 'Total Bill', 24.71],
#  [33, 'Thursday', 'Lunch', 'Tip', 5.85],
#  [33, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [33, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [33, 'Thursday', 'Lunch', 'Party Size', 2],
#  [33, 'Thursday', 'Lunch', 'Total Bill', 27.05],
#  [33, 'Thursday', 'Lunch', 'Tip', 5],
#  [33, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [33, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [33, 'Thursday', 'Lunch', 'Party Size', 6],
#  [33, 'Thursday', 'Lunch', 'Total Bill', 13],
#  [33, 'Thursday', 'Lunch', 'Tip', 2],
#  [33, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [33, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [33, 'Thursday', 'Lunch', 'Party Size', 2],
#  [34, 'Saturday', 'Dinner', 'Total Bill', 17.78],
#  [34, 'Saturday', 'Dinner', 'Tip', 3.27],
#  [34, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [34, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [34, 'Saturday', 'Dinner', 'Party Size', 2],
#  [34, 'Thursday', 'Lunch', 'Total Bill', 21.16],
#  [34, 'Thursday', 'Lunch', 'Tip', 3],
#  [34, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [34, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [34, 'Thursday', 'Lunch', 'Party Size', 2],
#  [34, 'Thursday', 'Lunch', 'Total Bill', 16.43],
#  [34, 'Thursday', 'Lunch', 'Tip', 2.3],
#  [34, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [34, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [34, 'Thursday', 'Lunch', 'Party Size', 2],
#  [34, 'Thursday', 'Lunch', 'Total Bill', 13.51],
#  [34, 'Thursday', 'Lunch', 'Tip', 2],
#  [34, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [34, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [34, 'Thursday', 'Lunch', 'Party Size', 2],
#  [35, 'Saturday', 'Dinner', 'Total Bill', 24.06],
#  [35, 'Saturday', 'Dinner', 'Tip', 3.6],
#  [35, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [35, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [35, 'Saturday', 'Dinner', 'Party Size', 3],
#  [35, 'Friday', 'Dinner', 'Total Bill', 28.97],
#  [35, 'Friday', 'Dinner', 'Tip', 3],
#  [35, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
#  [35, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [35, 'Friday', 'Dinner', 'Party Size', 2],
#  [35, 'Thursday', 'Lunch', 'Total Bill', 8.35],
#  [35, 'Thursday', 'Lunch', 'Tip', 1.5],
#  [35, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [35, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [35, 'Thursday', 'Lunch', 'Party Size', 2],
#  [35, 'Thursday', 'Lunch', 'Total Bill', 18.71],
#  [35, 'Thursday', 'Lunch', 'Tip', 4],
#  [35, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [35, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [35, 'Thursday', 'Lunch', 'Party Size', 3],
#  [36, 'Saturday', 'Dinner', 'Total Bill', 16.31],
#  [36, 'Saturday', 'Dinner', 'Tip', 2],
#  [36, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [36, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [36, 'Saturday', 'Dinner', 'Party Size', 3],
#  [36, 'Friday', 'Dinner', 'Total Bill', 22.49],
#  [36, 'Friday', 'Dinner', 'Tip', 3.5],
#  [36, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
#  [36, 'Friday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [36, 'Friday', 'Dinner', 'Party Size', 2],
#  [36, 'Thursday', 'Lunch', 'Total Bill', 18.64],
#  [36, 'Thursday', 'Lunch', 'Tip', 1.36],
#  [36, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [36, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [36, 'Thursday', 'Lunch', 'Party Size', 3],
#  [36, 'Thursday', 'Lunch', 'Total Bill', 12.74],
#  [36, 'Thursday', 'Lunch', 'Tip', 2.01],
#  [36, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [36, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [36, 'Thursday', 'Lunch', 'Party Size', 2],
#  [37, 'Saturday', 'Dinner', 'Total Bill', 16.93],
#  [37, 'Saturday', 'Dinner', 'Tip', 3.07],
#  [37, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
#  [37, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [37, 'Saturday', 'Dinner', 'Party Size', 3],
#  [37, 'Friday', 'Dinner', 'Total Bill', 5.75],
#  [37, 'Friday', 'Dinner', 'Tip', 1],
#  [37, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
#  [37, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [37, 'Friday', 'Dinner', 'Party Size', 2],
#  [37, 'Thursday', 'Lunch', 'Total Bill', 11.87],
#  [37, 'Thursday', 'Lunch', 'Tip', 1.63],
#  [37, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [37, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [37, 'Thursday', 'Lunch', 'Party Size', 2],
#  [37, 'Thursday', 'Lunch', 'Total Bill', 13],
#  [37, 'Thursday', 'Lunch', 'Tip', 2],
#  [37, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [37, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [37, 'Thursday', 'Lunch', 'Party Size', 2],
#  [38, 'Saturday', 'Dinner', 'Total Bill', 18.69],
#  [38, 'Saturday', 'Dinner', 'Tip', 2.31],
#  [38, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [38, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [38, 'Saturday', 'Dinner', 'Party Size', 3],
#  [38, 'Friday', 'Dinner', 'Total Bill', 16.32],
#  [38, 'Friday', 'Dinner', 'Tip', 4.3],
#  [38, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
#  [38, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [38, 'Friday', 'Dinner', 'Party Size', 2],
#  [38, 'Thursday', 'Lunch', 'Total Bill', 9.78],
#  [38, 'Thursday', 'Lunch', 'Tip', 1.73],
#  [38, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [38, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [38, 'Thursday', 'Lunch', 'Party Size', 2],
#  [38, 'Thursday', 'Lunch', 'Total Bill', 16.4],
#  [38, 'Thursday', 'Lunch', 'Tip', 2.5],
#  [38, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [38, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [38, 'Thursday', 'Lunch', 'Party Size', 2],
#  [39, 'Saturday', 'Dinner', 'Total Bill', 31.27],
#  [39, 'Saturday', 'Dinner', 'Tip', 5],
#  [39, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [39, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [39, 'Saturday', 'Dinner', 'Party Size', 3],
#  [39, 'Friday', 'Dinner', 'Total Bill', 22.75],
#  [39, 'Friday', 'Dinner', 'Tip', 3.25],
#  [39, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
#  [39, 'Friday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [39, 'Friday', 'Dinner', 'Party Size', 2],
#  [39, 'Thursday', 'Lunch', 'Total Bill', 7.51],
#  [39, 'Thursday', 'Lunch', 'Tip', 2],
#  [39, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [39, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
#  [39, 'Thursday', 'Lunch', 'Party Size', 2],
#  [39, 'Thursday', 'Lunch', 'Total Bill', 20.53],
#  [39, 'Thursday', 'Lunch', 'Tip', 4],
#  [39, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
#  [39, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [39, 'Thursday', 'Lunch', 'Party Size', 4],
#  [40, 'Saturday', 'Dinner', 'Total Bill', 16.04],
#  [40, 'Saturday', 'Dinner', 'Tip', 2.24],
#  [40, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [40, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [40, 'Saturday', 'Dinner', 'Party Size', 3],
#  [40, 'Friday', 'Dinner', 'Total Bill', 40.17],
#  [40, 'Friday', 'Dinner', 'Tip', 4.73],
#  [40, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
#  [40, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [40, 'Friday', 'Dinner', 'Party Size', 4],
#  [40, 'Sunday', 'Dinner', 'Total Bill', 14.07],
#  [40, 'Sunday', 'Dinner', 'Tip', 2.5],
#  [40, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [40, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [40, 'Sunday', 'Dinner', 'Party Size', 2],
#  [40, 'Thursday', 'Lunch', 'Total Bill', 16.47],
#  [40, 'Thursday', 'Lunch', 'Tip', 3.23],
#  [40, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
#  [40, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
#  [40, 'Thursday', 'Lunch', 'Party Size', 3],
#  [41, 'Sunday', 'Dinner', 'Total Bill', 17.46],
#  [41, 'Sunday', 'Dinner', 'Tip', 2.54],
#  [41, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [41, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [41, 'Sunday', 'Dinner', 'Party Size', 2],
#  [41, 'Friday', 'Dinner', 'Total Bill', 27.28],
#  [41, 'Friday', 'Dinner', 'Tip', 4],
#  [41, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
#  [41, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [41, 'Friday', 'Dinner', 'Party Size', 2],
#  [41, 'Sunday', 'Dinner', 'Total Bill', 13.13],
#  [41, 'Sunday', 'Dinner', 'Tip', 2],
#  [41, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [41, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [41, 'Sunday', 'Dinner', 'Party Size', 2],
#  [41, 'Saturday', 'Dinner', 'Total Bill', 26.59],
#  [41, 'Saturday', 'Dinner', 'Tip', 3.41],
#  [41, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [41, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [41, 'Saturday', 'Dinner', 'Party Size', 3],
#  [42, 'Sunday', 'Dinner', 'Total Bill', 13.94],
#  [42, 'Sunday', 'Dinner', 'Tip', 3.06],
#  [42, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [42, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [42, 'Sunday', 'Dinner', 'Party Size', 2],
#  [42, 'Friday', 'Dinner', 'Total Bill', 12.03],
#  [42, 'Friday', 'Dinner', 'Tip', 1.5],
#  [42, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
#  [42, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [42, 'Friday', 'Dinner', 'Party Size', 2],
#  [42, 'Sunday', 'Dinner', 'Total Bill', 17.26],
#  [42, 'Sunday', 'Dinner', 'Tip', 2.74],
#  [42, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [42, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [42, 'Sunday', 'Dinner', 'Party Size', 3],
#  [42, 'Saturday', 'Dinner', 'Total Bill', 38.73],
#  [42, 'Saturday', 'Dinner', 'Tip', 3],
#  [42, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [42, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [42, 'Saturday', 'Dinner', 'Party Size', 4],
#  [43, 'Sunday', 'Dinner', 'Total Bill', 9.68],
#  [43, 'Sunday', 'Dinner', 'Tip', 1.32],
#  [43, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [43, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [43, 'Sunday', 'Dinner', 'Party Size', 2],
#  [43, 'Friday', 'Dinner', 'Total Bill', 21.01],
#  [43, 'Friday', 'Dinner', 'Tip', 3],
#  [43, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
#  [43, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [43, 'Friday', 'Dinner', 'Party Size', 2],
#  [43, 'Sunday', 'Dinner', 'Total Bill', 24.55],
#  [43, 'Sunday', 'Dinner', 'Tip', 2],
#  [43, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
#  [43, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
#  [43, 'Sunday', 'Dinner', 'Party Size', 4],
#  [43, 'Saturday', 'Dinner', 'Total Bill', 24.27],
#  [43, 'Saturday', 'Dinner', 'Tip', 2.03],
#  [43, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
#  [43, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
#  [43, 'Saturday', 'Dinner', 'Party Size', 2],
#  ...]

# %%
id, gender, smoker = norm_tips[0][0], None, None
for i, rec in enumerate(norm_tips):
    if rec[0] != id:
        id = rec[0]
        gender, smoker = None, None
    if rec[2] == 'Payer Gender':
        rec[3] = gender if gender else rec[3]
        gender = rec[3]
    elif rec[2] == 'Payer Smoker':
        rec[3] = smoker if smoker else rec[3]
        smoker = rec[3]

norm_tips.insert(0, ["record_id", "day of week", "attribute", "value"])

# %%
for rec in norm_tips:
    print(f"{rec},")
# Out:
# ['record_id', 'day of week', 'attribute', 'value'],
# [0, 'Sunday', 'Dinner', 'Total Bill', 16.99],
# [0, 'Sunday', 'Dinner', 'Tip', 1.01],
# [0, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [0, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [0, 'Sunday', 'Dinner', 'Party Size', 2],
# [0, 'Sunday', 'Dinner', 'Total Bill', 19.49],
# [0, 'Sunday', 'Dinner', 'Tip', 3.51],
# [0, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [0, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [0, 'Sunday', 'Dinner', 'Party Size', 2],
# [0, 'Saturday', 'Dinner', 'Total Bill', 14],
# [0, 'Saturday', 'Dinner', 'Tip', 3],
# [0, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [0, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [0, 'Saturday', 'Dinner', 'Party Size', 2],
# [0, 'Sunday', 'Dinner', 'Total Bill', 24.52],
# [0, 'Sunday', 'Dinner', 'Tip', 3.48],
# [0, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [0, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [0, 'Sunday', 'Dinner', 'Party Size', 3],
# [0, 'Friday', 'Lunch', 'Total Bill', 12.16],
# [0, 'Friday', 'Lunch', 'Tip', 2.2],
# [0, 'Friday', 'Lunch', 'Payer Gender', 'Male'],
# [0, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [0, 'Friday', 'Lunch', 'Party Size', 2],
# [1, 'Sunday', 'Dinner', 'Total Bill', 10.34],
# [1, 'Sunday', 'Dinner', 'Tip', 1.66],
# [1, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [1, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [1, 'Sunday', 'Dinner', 'Party Size', 3],
# [1, 'Saturday', 'Dinner', 'Total Bill', 38.01],
# [1, 'Saturday', 'Dinner', 'Tip', 3],
# [1, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [1, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [1, 'Saturday', 'Dinner', 'Party Size', 4],
# [1, 'Saturday', 'Dinner', 'Total Bill', 7.25],
# [1, 'Saturday', 'Dinner', 'Tip', 1],
# [1, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [1, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [1, 'Saturday', 'Dinner', 'Party Size', 1],
# [1, 'Sunday', 'Dinner', 'Total Bill', 20.76],
# [1, 'Sunday', 'Dinner', 'Tip', 2.24],
# [1, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [1, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [1, 'Sunday', 'Dinner', 'Party Size', 2],
# [1, 'Friday', 'Lunch', 'Total Bill', 13.42],
# [1, 'Friday', 'Lunch', 'Tip', 3.48],
# [1, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
# [1, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [1, 'Friday', 'Lunch', 'Party Size', 2],
# [2, 'Sunday', 'Dinner', 'Total Bill', 21.01],
# [2, 'Sunday', 'Dinner', 'Tip', 3.5],
# [2, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [2, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [2, 'Sunday', 'Dinner', 'Party Size', 3],
# [2, 'Saturday', 'Dinner', 'Total Bill', 26.41],
# [2, 'Saturday', 'Dinner', 'Tip', 1.5],
# [2, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [2, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [2, 'Saturday', 'Dinner', 'Party Size', 2],
# [2, 'Sunday', 'Dinner', 'Total Bill', 38.07],
# [2, 'Sunday', 'Dinner', 'Tip', 4],
# [2, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [2, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [2, 'Sunday', 'Dinner', 'Party Size', 3],
# [2, 'Sunday', 'Dinner', 'Total Bill', 31.71],
# [2, 'Sunday', 'Dinner', 'Tip', 4.5],
# [2, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [2, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [2, 'Sunday', 'Dinner', 'Party Size', 4],
# [2, 'Friday', 'Lunch', 'Total Bill', 8.58],
# [2, 'Friday', 'Lunch', 'Tip', 1.92],
# [2, 'Friday', 'Lunch', 'Payer Gender', 'Male'],
# [2, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [2, 'Friday', 'Lunch', 'Party Size', 1],
# [3, 'Sunday', 'Dinner', 'Total Bill', 23.68],
# [3, 'Sunday', 'Dinner', 'Tip', 3.31],
# [3, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [3, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [3, 'Sunday', 'Dinner', 'Party Size', 2],
# [3, 'Saturday', 'Dinner', 'Total Bill', 11.24],
# [3, 'Saturday', 'Dinner', 'Tip', 1.76],
# [3, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [3, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [3, 'Saturday', 'Dinner', 'Party Size', 2],
# [3, 'Sunday', 'Dinner', 'Total Bill', 23.95],
# [3, 'Sunday', 'Dinner', 'Tip', 2.55],
# [3, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [3, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [3, 'Sunday', 'Dinner', 'Party Size', 2],
# [3, 'Saturday', 'Dinner', 'Total Bill', 10.59],
# [3, 'Saturday', 'Dinner', 'Tip', 1.61],
# [3, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [3, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [3, 'Saturday', 'Dinner', 'Party Size', 2],
# [3, 'Friday', 'Lunch', 'Total Bill', 15.98],
# [3, 'Friday', 'Lunch', 'Tip', 3],
# [3, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
# [3, 'Friday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [3, 'Friday', 'Lunch', 'Party Size', 3],
# [4, 'Sunday', 'Dinner', 'Total Bill', 24.59],
# [4, 'Sunday', 'Dinner', 'Tip', 3.61],
# [4, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [4, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [4, 'Sunday', 'Dinner', 'Party Size', 4],
# [4, 'Saturday', 'Dinner', 'Total Bill', 48.27],
# [4, 'Saturday', 'Dinner', 'Tip', 6.73],
# [4, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [4, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [4, 'Saturday', 'Dinner', 'Party Size', 4],
# [4, 'Sunday', 'Dinner', 'Total Bill', 25.71],
# [4, 'Sunday', 'Dinner', 'Tip', 4],
# [4, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [4, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [4, 'Sunday', 'Dinner', 'Party Size', 3],
# [4, 'Saturday', 'Dinner', 'Total Bill', 10.63],
# [4, 'Saturday', 'Dinner', 'Tip', 2],
# [4, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [4, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [4, 'Saturday', 'Dinner', 'Party Size', 2],
# [4, 'Friday', 'Lunch', 'Total Bill', 13.42],
# [4, 'Friday', 'Lunch', 'Tip', 1.58],
# [4, 'Friday', 'Lunch', 'Payer Gender', 'Male'],
# [4, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [4, 'Friday', 'Lunch', 'Party Size', 2],
# [5, 'Sunday', 'Dinner', 'Total Bill', 25.29],
# [5, 'Sunday', 'Dinner', 'Tip', 4.71],
# [5, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [5, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [5, 'Sunday', 'Dinner', 'Party Size', 4],
# [5, 'Saturday', 'Dinner', 'Total Bill', 20.29],
# [5, 'Saturday', 'Dinner', 'Tip', 3.21],
# [5, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [5, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [5, 'Saturday', 'Dinner', 'Party Size', 2],
# [5, 'Sunday', 'Dinner', 'Total Bill', 17.31],
# [5, 'Sunday', 'Dinner', 'Tip', 3.5],
# [5, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [5, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [5, 'Sunday', 'Dinner', 'Party Size', 2],
# [5, 'Saturday', 'Dinner', 'Total Bill', 50.81],
# [5, 'Saturday', 'Dinner', 'Tip', 10],
# [5, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [5, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [5, 'Saturday', 'Dinner', 'Party Size', 3],
# [5, 'Friday', 'Lunch', 'Total Bill', 16.27],
# [5, 'Friday', 'Lunch', 'Tip', 2.5],
# [5, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
# [5, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [5, 'Friday', 'Lunch', 'Party Size', 2],
# [6, 'Sunday', 'Dinner', 'Total Bill', 8.77],
# [6, 'Sunday', 'Dinner', 'Tip', 2],
# [6, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [6, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [6, 'Sunday', 'Dinner', 'Party Size', 2],
# [6, 'Saturday', 'Dinner', 'Total Bill', 13.81],
# [6, 'Saturday', 'Dinner', 'Tip', 2],
# [6, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [6, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [6, 'Saturday', 'Dinner', 'Party Size', 2],
# [6, 'Sunday', 'Dinner', 'Total Bill', 29.93],
# [6, 'Sunday', 'Dinner', 'Tip', 5.07],
# [6, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [6, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [6, 'Sunday', 'Dinner', 'Party Size', 4],
# [6, 'Saturday', 'Dinner', 'Total Bill', 15.81],
# [6, 'Saturday', 'Dinner', 'Tip', 3.16],
# [6, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [6, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [6, 'Saturday', 'Dinner', 'Party Size', 2],
# [6, 'Friday', 'Lunch', 'Total Bill', 10.09],
# [6, 'Friday', 'Lunch', 'Tip', 2],
# [6, 'Friday', 'Lunch', 'Payer Gender', 'Female'],
# [6, 'Friday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [6, 'Friday', 'Lunch', 'Party Size', 2],
# [7, 'Sunday', 'Dinner', 'Total Bill', 26.88],
# [7, 'Sunday', 'Dinner', 'Tip', 3.12],
# [7, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [7, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [7, 'Sunday', 'Dinner', 'Party Size', 4],
# [7, 'Saturday', 'Dinner', 'Total Bill', 11.02],
# [7, 'Saturday', 'Dinner', 'Tip', 1.98],
# [7, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [7, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [7, 'Saturday', 'Dinner', 'Party Size', 2],
# [7, 'Thursday', 'Lunch', 'Total Bill', 10.65],
# [7, 'Thursday', 'Lunch', 'Tip', 1.5],
# [7, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [7, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [7, 'Thursday', 'Lunch', 'Party Size', 2],
# [7, 'Sunday', 'Dinner', 'Total Bill', 7.25],
# [7, 'Sunday', 'Dinner', 'Tip', 5.15],
# [7, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [7, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [7, 'Sunday', 'Dinner', 'Party Size', 2],
# [7, 'Saturday', 'Dinner', 'Total Bill', 20.45],
# [7, 'Saturday', 'Dinner', 'Tip', 3],
# [7, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [7, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [7, 'Saturday', 'Dinner', 'Party Size', 4],
# [8, 'Sunday', 'Dinner', 'Total Bill', 15.04],
# [8, 'Sunday', 'Dinner', 'Tip', 1.96],
# [8, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [8, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [8, 'Sunday', 'Dinner', 'Party Size', 2],
# [8, 'Saturday', 'Dinner', 'Total Bill', 18.29],
# [8, 'Saturday', 'Dinner', 'Tip', 3.76],
# [8, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [8, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [8, 'Saturday', 'Dinner', 'Party Size', 4],
# [8, 'Thursday', 'Lunch', 'Total Bill', 12.43],
# [8, 'Thursday', 'Lunch', 'Tip', 1.8],
# [8, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [8, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [8, 'Thursday', 'Lunch', 'Party Size', 2],
# [8, 'Sunday', 'Dinner', 'Total Bill', 31.85],
# [8, 'Sunday', 'Dinner', 'Tip', 3.18],
# [8, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [8, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [8, 'Sunday', 'Dinner', 'Party Size', 2],
# [8, 'Saturday', 'Dinner', 'Total Bill', 13.28],
# [8, 'Saturday', 'Dinner', 'Tip', 2.72],
# [8, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [8, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [8, 'Saturday', 'Dinner', 'Party Size', 2],
# [9, 'Sunday', 'Dinner', 'Total Bill', 14.78],
# [9, 'Sunday', 'Dinner', 'Tip', 3.23],
# [9, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [9, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [9, 'Sunday', 'Dinner', 'Party Size', 2],
# [9, 'Saturday', 'Dinner', 'Total Bill', 17.59],
# [9, 'Saturday', 'Dinner', 'Tip', 2.64],
# [9, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [9, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [9, 'Saturday', 'Dinner', 'Party Size', 3],
# [9, 'Thursday', 'Lunch', 'Total Bill', 24.08],
# [9, 'Thursday', 'Lunch', 'Tip', 2.92],
# [9, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [9, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [9, 'Thursday', 'Lunch', 'Party Size', 4],
# [9, 'Sunday', 'Dinner', 'Total Bill', 16.82],
# [9, 'Sunday', 'Dinner', 'Tip', 4],
# [9, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [9, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [9, 'Sunday', 'Dinner', 'Party Size', 2],
# [9, 'Saturday', 'Dinner', 'Total Bill', 22.12],
# [9, 'Saturday', 'Dinner', 'Tip', 2.88],
# [9, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [9, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [9, 'Saturday', 'Dinner', 'Party Size', 2],
# [10, 'Sunday', 'Dinner', 'Total Bill', 10.27],
# [10, 'Sunday', 'Dinner', 'Tip', 1.71],
# [10, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [10, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [10, 'Sunday', 'Dinner', 'Party Size', 2],
# [10, 'Saturday', 'Dinner', 'Total Bill', 20.08],
# [10, 'Saturday', 'Dinner', 'Tip', 3.15],
# [10, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [10, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [10, 'Saturday', 'Dinner', 'Party Size', 3],
# [10, 'Thursday', 'Lunch', 'Total Bill', 11.69],
# [10, 'Thursday', 'Lunch', 'Tip', 2.31],
# [10, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [10, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [10, 'Thursday', 'Lunch', 'Party Size', 2],
# [10, 'Sunday', 'Dinner', 'Total Bill', 32.9],
# [10, 'Sunday', 'Dinner', 'Tip', 3.11],
# [10, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [10, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [10, 'Sunday', 'Dinner', 'Party Size', 2],
# [10, 'Saturday', 'Dinner', 'Total Bill', 24.01],
# [10, 'Saturday', 'Dinner', 'Tip', 2],
# [10, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [10, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [10, 'Saturday', 'Dinner', 'Party Size', 4],
# [11, 'Sunday', 'Dinner', 'Total Bill', 35.26],
# [11, 'Sunday', 'Dinner', 'Tip', 5],
# [11, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [11, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [11, 'Sunday', 'Dinner', 'Party Size', 4],
# [11, 'Saturday', 'Dinner', 'Total Bill', 16.45],
# [11, 'Saturday', 'Dinner', 'Tip', 2.47],
# [11, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [11, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [11, 'Saturday', 'Dinner', 'Party Size', 2],
# [11, 'Thursday', 'Lunch', 'Total Bill', 13.42],
# [11, 'Thursday', 'Lunch', 'Tip', 1.68],
# [11, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [11, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [11, 'Thursday', 'Lunch', 'Party Size', 2],
# [11, 'Sunday', 'Dinner', 'Total Bill', 17.89],
# [11, 'Sunday', 'Dinner', 'Tip', 2],
# [11, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [11, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [11, 'Sunday', 'Dinner', 'Party Size', 2],
# [11, 'Saturday', 'Dinner', 'Total Bill', 15.69],
# [11, 'Saturday', 'Dinner', 'Tip', 3],
# [11, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [11, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [11, 'Saturday', 'Dinner', 'Party Size', 3],
# [12, 'Sunday', 'Dinner', 'Total Bill', 15.42],
# [12, 'Sunday', 'Dinner', 'Tip', 1.57],
# [12, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [12, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [12, 'Sunday', 'Dinner', 'Party Size', 2],
# [12, 'Saturday', 'Dinner', 'Total Bill', 3.07],
# [12, 'Saturday', 'Dinner', 'Tip', 1],
# [12, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [12, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [12, 'Saturday', 'Dinner', 'Party Size', 1],
# [12, 'Thursday', 'Lunch', 'Total Bill', 14.26],
# [12, 'Thursday', 'Lunch', 'Tip', 2.5],
# [12, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [12, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [12, 'Thursday', 'Lunch', 'Party Size', 2],
# [12, 'Sunday', 'Dinner', 'Total Bill', 14.48],
# [12, 'Sunday', 'Dinner', 'Tip', 2],
# [12, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [12, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [12, 'Sunday', 'Dinner', 'Party Size', 2],
# [12, 'Saturday', 'Dinner', 'Total Bill', 11.61],
# [12, 'Saturday', 'Dinner', 'Tip', 3.39],
# [12, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [12, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [12, 'Saturday', 'Dinner', 'Party Size', 2],
# [13, 'Sunday', 'Dinner', 'Total Bill', 18.43],
# [13, 'Sunday', 'Dinner', 'Tip', 3],
# [13, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [13, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [13, 'Sunday', 'Dinner', 'Party Size', 4],
# [13, 'Saturday', 'Dinner', 'Total Bill', 20.23],
# [13, 'Saturday', 'Dinner', 'Tip', 2.01],
# [13, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [13, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [13, 'Saturday', 'Dinner', 'Party Size', 2],
# [13, 'Thursday', 'Lunch', 'Total Bill', 15.95],
# [13, 'Thursday', 'Lunch', 'Tip', 2],
# [13, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [13, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [13, 'Thursday', 'Lunch', 'Party Size', 2],
# [13, 'Sunday', 'Dinner', 'Total Bill', 9.6],
# [13, 'Sunday', 'Dinner', 'Tip', 4],
# [13, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [13, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [13, 'Sunday', 'Dinner', 'Party Size', 2],
# [13, 'Saturday', 'Dinner', 'Total Bill', 10.77],
# [13, 'Saturday', 'Dinner', 'Tip', 1.47],
# [13, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [13, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [13, 'Saturday', 'Dinner', 'Party Size', 2],
# [14, 'Sunday', 'Dinner', 'Total Bill', 14.83],
# [14, 'Sunday', 'Dinner', 'Tip', 3.02],
# [14, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [14, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [14, 'Sunday', 'Dinner', 'Party Size', 2],
# [14, 'Saturday', 'Dinner', 'Total Bill', 15.01],
# [14, 'Saturday', 'Dinner', 'Tip', 2.09],
# [14, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [14, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [14, 'Saturday', 'Dinner', 'Party Size', 2],
# [14, 'Thursday', 'Lunch', 'Total Bill', 12.48],
# [14, 'Thursday', 'Lunch', 'Tip', 2.52],
# [14, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [14, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [14, 'Thursday', 'Lunch', 'Party Size', 2],
# [14, 'Sunday', 'Dinner', 'Total Bill', 34.63],
# [14, 'Sunday', 'Dinner', 'Tip', 3.55],
# [14, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [14, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [14, 'Sunday', 'Dinner', 'Party Size', 2],
# [14, 'Saturday', 'Dinner', 'Total Bill', 15.53],
# [14, 'Saturday', 'Dinner', 'Tip', 3],
# [14, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [14, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [14, 'Saturday', 'Dinner', 'Party Size', 2],
# [15, 'Sunday', 'Dinner', 'Total Bill', 21.58],
# [15, 'Sunday', 'Dinner', 'Tip', 3.92],
# [15, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [15, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [15, 'Sunday', 'Dinner', 'Party Size', 2],
# [15, 'Saturday', 'Dinner', 'Total Bill', 12.02],
# [15, 'Saturday', 'Dinner', 'Tip', 1.97],
# [15, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [15, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [15, 'Saturday', 'Dinner', 'Party Size', 2],
# [15, 'Thursday', 'Lunch', 'Total Bill', 29.8],
# [15, 'Thursday', 'Lunch', 'Tip', 4.2],
# [15, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [15, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [15, 'Thursday', 'Lunch', 'Party Size', 6],
# [15, 'Sunday', 'Dinner', 'Total Bill', 34.65],
# [15, 'Sunday', 'Dinner', 'Tip', 3.68],
# [15, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [15, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [15, 'Sunday', 'Dinner', 'Party Size', 4],
# [15, 'Saturday', 'Dinner', 'Total Bill', 10.07],
# [15, 'Saturday', 'Dinner', 'Tip', 1.25],
# [15, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [15, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [15, 'Saturday', 'Dinner', 'Party Size', 2],
# [16, 'Sunday', 'Dinner', 'Total Bill', 10.33],
# [16, 'Sunday', 'Dinner', 'Tip', 1.67],
# [16, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [16, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [16, 'Sunday', 'Dinner', 'Party Size', 3],
# [16, 'Saturday', 'Dinner', 'Total Bill', 17.07],
# [16, 'Saturday', 'Dinner', 'Tip', 3],
# [16, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [16, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [16, 'Saturday', 'Dinner', 'Party Size', 3],
# [16, 'Thursday', 'Lunch', 'Total Bill', 8.52],
# [16, 'Thursday', 'Lunch', 'Tip', 1.48],
# [16, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [16, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [16, 'Thursday', 'Lunch', 'Party Size', 2],
# [16, 'Sunday', 'Dinner', 'Total Bill', 23.33],
# [16, 'Sunday', 'Dinner', 'Tip', 5.65],
# [16, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [16, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [16, 'Sunday', 'Dinner', 'Party Size', 2],
# [16, 'Saturday', 'Dinner', 'Total Bill', 12.6],
# [16, 'Saturday', 'Dinner', 'Tip', 1],
# [16, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [16, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [16, 'Saturday', 'Dinner', 'Party Size', 2],
# [17, 'Sunday', 'Dinner', 'Total Bill', 16.29],
# [17, 'Sunday', 'Dinner', 'Tip', 3.71],
# [17, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [17, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [17, 'Sunday', 'Dinner', 'Party Size', 3],
# [17, 'Saturday', 'Dinner', 'Total Bill', 26.86],
# [17, 'Saturday', 'Dinner', 'Tip', 3.14],
# [17, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [17, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [17, 'Saturday', 'Dinner', 'Party Size', 2],
# [17, 'Thursday', 'Lunch', 'Total Bill', 14.52],
# [17, 'Thursday', 'Lunch', 'Tip', 2],
# [17, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [17, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [17, 'Thursday', 'Lunch', 'Party Size', 2],
# [17, 'Sunday', 'Dinner', 'Total Bill', 45.35],
# [17, 'Sunday', 'Dinner', 'Tip', 3.5],
# [17, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [17, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [17, 'Sunday', 'Dinner', 'Party Size', 3],
# [17, 'Saturday', 'Dinner', 'Total Bill', 32.83],
# [17, 'Saturday', 'Dinner', 'Tip', 1.17],
# [17, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [17, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [17, 'Saturday', 'Dinner', 'Party Size', 2],
# [18, 'Sunday', 'Dinner', 'Total Bill', 16.97],
# [18, 'Sunday', 'Dinner', 'Tip', 3.5],
# [18, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [18, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [18, 'Sunday', 'Dinner', 'Party Size', 3],
# [18, 'Saturday', 'Dinner', 'Total Bill', 25.28],
# [18, 'Saturday', 'Dinner', 'Tip', 5],
# [18, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [18, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [18, 'Saturday', 'Dinner', 'Party Size', 2],
# [18, 'Thursday', 'Lunch', 'Total Bill', 11.38],
# [18, 'Thursday', 'Lunch', 'Tip', 2],
# [18, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [18, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [18, 'Thursday', 'Lunch', 'Party Size', 2],
# [18, 'Sunday', 'Dinner', 'Total Bill', 23.17],
# [18, 'Sunday', 'Dinner', 'Tip', 6.5],
# [18, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [18, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [18, 'Sunday', 'Dinner', 'Party Size', 4],
# [18, 'Saturday', 'Dinner', 'Total Bill', 35.83],
# [18, 'Saturday', 'Dinner', 'Tip', 4.67],
# [18, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [18, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [18, 'Saturday', 'Dinner', 'Party Size', 3],
# [19, 'Saturday', 'Dinner', 'Total Bill', 20.65],
# [19, 'Saturday', 'Dinner', 'Tip', 3.35],
# [19, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [19, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [19, 'Saturday', 'Dinner', 'Party Size', 3],
# [19, 'Saturday', 'Dinner', 'Total Bill', 14.73],
# [19, 'Saturday', 'Dinner', 'Tip', 2.2],
# [19, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [19, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [19, 'Saturday', 'Dinner', 'Party Size', 2],
# [19, 'Thursday', 'Lunch', 'Total Bill', 22.82],
# [19, 'Thursday', 'Lunch', 'Tip', 2.18],
# [19, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [19, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [19, 'Thursday', 'Lunch', 'Party Size', 3],
# [19, 'Sunday', 'Dinner', 'Total Bill', 40.55],
# [19, 'Sunday', 'Dinner', 'Tip', 3],
# [19, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [19, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [19, 'Sunday', 'Dinner', 'Party Size', 2],
# [19, 'Saturday', 'Dinner', 'Total Bill', 29.03],
# [19, 'Saturday', 'Dinner', 'Tip', 5.92],
# [19, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [19, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [19, 'Saturday', 'Dinner', 'Party Size', 3],
# [20, 'Saturday', 'Dinner', 'Total Bill', 17.92],
# [20, 'Saturday', 'Dinner', 'Tip', 4.08],
# [20, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [20, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [20, 'Saturday', 'Dinner', 'Party Size', 2],
# [20, 'Saturday', 'Dinner', 'Total Bill', 10.51],
# [20, 'Saturday', 'Dinner', 'Tip', 1.25],
# [20, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [20, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [20, 'Saturday', 'Dinner', 'Party Size', 2],
# [20, 'Thursday', 'Lunch', 'Total Bill', 19.08],
# [20, 'Thursday', 'Lunch', 'Tip', 1.5],
# [20, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [20, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [20, 'Thursday', 'Lunch', 'Party Size', 2],
# [20, 'Sunday', 'Dinner', 'Total Bill', 20.69],
# [20, 'Sunday', 'Dinner', 'Tip', 5],
# [20, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [20, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [20, 'Sunday', 'Dinner', 'Party Size', 5],
# [20, 'Saturday', 'Dinner', 'Total Bill', 27.18],
# [20, 'Saturday', 'Dinner', 'Tip', 2],
# [20, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [20, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [20, 'Saturday', 'Dinner', 'Party Size', 2],
# [21, 'Saturday', 'Dinner', 'Total Bill', 20.29],
# [21, 'Saturday', 'Dinner', 'Tip', 2.75],
# [21, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [21, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [21, 'Saturday', 'Dinner', 'Party Size', 2],
# [21, 'Saturday', 'Dinner', 'Total Bill', 17.92],
# [21, 'Saturday', 'Dinner', 'Tip', 3.08],
# [21, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [21, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [21, 'Saturday', 'Dinner', 'Party Size', 2],
# [21, 'Thursday', 'Lunch', 'Total Bill', 20.27],
# [21, 'Thursday', 'Lunch', 'Tip', 2.83],
# [21, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [21, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [21, 'Thursday', 'Lunch', 'Party Size', 2],
# [21, 'Sunday', 'Dinner', 'Total Bill', 20.9],
# [21, 'Sunday', 'Dinner', 'Tip', 3.5],
# [21, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [21, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [21, 'Sunday', 'Dinner', 'Party Size', 3],
# [21, 'Saturday', 'Dinner', 'Total Bill', 22.67],
# [21, 'Saturday', 'Dinner', 'Tip', 2],
# [21, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [21, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [21, 'Saturday', 'Dinner', 'Party Size', 2],
# [22, 'Saturday', 'Dinner', 'Total Bill', 15.77],
# [22, 'Saturday', 'Dinner', 'Tip', 2.23],
# [22, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [22, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [22, 'Saturday', 'Dinner', 'Party Size', 2],
# [22, 'Thursday', 'Lunch', 'Total Bill', 27.2],
# [22, 'Thursday', 'Lunch', 'Tip', 4],
# [22, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [22, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [22, 'Thursday', 'Lunch', 'Party Size', 4],
# [22, 'Thursday', 'Lunch', 'Total Bill', 11.17],
# [22, 'Thursday', 'Lunch', 'Tip', 1.5],
# [22, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [22, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [22, 'Thursday', 'Lunch', 'Party Size', 2],
# [22, 'Sunday', 'Dinner', 'Total Bill', 30.46],
# [22, 'Sunday', 'Dinner', 'Tip', 2],
# [22, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [22, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [22, 'Sunday', 'Dinner', 'Party Size', 5],
# [22, 'Saturday', 'Dinner', 'Total Bill', 17.82],
# [22, 'Saturday', 'Dinner', 'Tip', 1.75],
# [22, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [22, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [22, 'Saturday', 'Dinner', 'Party Size', 2],
# [23, 'Saturday', 'Dinner', 'Total Bill', 39.42],
# [23, 'Saturday', 'Dinner', 'Tip', 7.58],
# [23, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [23, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [23, 'Saturday', 'Dinner', 'Party Size', 4],
# [23, 'Thursday', 'Lunch', 'Total Bill', 22.76],
# [23, 'Thursday', 'Lunch', 'Tip', 3],
# [23, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [23, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [23, 'Thursday', 'Lunch', 'Party Size', 2],
# [23, 'Thursday', 'Lunch', 'Total Bill', 12.26],
# [23, 'Thursday', 'Lunch', 'Tip', 2],
# [23, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [23, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [23, 'Thursday', 'Lunch', 'Party Size', 2],
# [23, 'Sunday', 'Dinner', 'Total Bill', 18.15],
# [23, 'Sunday', 'Dinner', 'Tip', 3.5],
# [23, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [23, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [23, 'Sunday', 'Dinner', 'Party Size', 3],
# [23, 'Thursday', 'Dinner', 'Total Bill', 18.78],
# [23, 'Thursday', 'Dinner', 'Tip', 3],
# [23, 'Thursday', 'Dinner', 'Payer Gender', 'Female'],
# [23, 'Thursday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [23, 'Thursday', 'Dinner', 'Party Size', 2],
# [24, 'Saturday', 'Dinner', 'Total Bill', 19.82],
# [24, 'Saturday', 'Dinner', 'Tip', 3.18],
# [24, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [24, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [24, 'Saturday', 'Dinner', 'Party Size', 2],
# [24, 'Thursday', 'Lunch', 'Total Bill', 17.29],
# [24, 'Thursday', 'Lunch', 'Tip', 2.71],
# [24, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [24, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [24, 'Thursday', 'Lunch', 'Party Size', 2],
# [24, 'Thursday', 'Lunch', 'Total Bill', 18.26],
# [24, 'Thursday', 'Lunch', 'Tip', 3.25],
# [24, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [24, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [24, 'Thursday', 'Lunch', 'Party Size', 2],
# [24, 'Sunday', 'Dinner', 'Total Bill', 23.1],
# [24, 'Sunday', 'Dinner', 'Tip', 4],
# [24, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [24, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [24, 'Sunday', 'Dinner', 'Party Size', 3],
# [25, 'Saturday', 'Dinner', 'Total Bill', 17.81],
# [25, 'Saturday', 'Dinner', 'Tip', 2.34],
# [25, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [25, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [25, 'Saturday', 'Dinner', 'Party Size', 4],
# [25, 'Thursday', 'Lunch', 'Total Bill', 19.44],
# [25, 'Thursday', 'Lunch', 'Tip', 3],
# [25, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [25, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [25, 'Thursday', 'Lunch', 'Party Size', 2],
# [25, 'Thursday', 'Lunch', 'Total Bill', 8.51],
# [25, 'Thursday', 'Lunch', 'Tip', 1.25],
# [25, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [25, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [25, 'Thursday', 'Lunch', 'Party Size', 2],
# [25, 'Sunday', 'Dinner', 'Total Bill', 15.69],
# [25, 'Sunday', 'Dinner', 'Tip', 1.5],
# [25, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [25, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [25, 'Sunday', 'Dinner', 'Party Size', 2],
# [26, 'Saturday', 'Dinner', 'Total Bill', 13.37],
# [26, 'Saturday', 'Dinner', 'Tip', 2],
# [26, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [26, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [26, 'Saturday', 'Dinner', 'Party Size', 2],
# [26, 'Thursday', 'Lunch', 'Total Bill', 16.66],
# [26, 'Thursday', 'Lunch', 'Tip', 3.4],
# [26, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [26, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [26, 'Thursday', 'Lunch', 'Party Size', 2],
# [26, 'Thursday', 'Lunch', 'Total Bill', 10.33],
# [26, 'Thursday', 'Lunch', 'Tip', 2],
# [26, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [26, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [26, 'Thursday', 'Lunch', 'Party Size', 2],
# [26, 'Thursday', 'Lunch', 'Total Bill', 19.81],
# [26, 'Thursday', 'Lunch', 'Tip', 4.19],
# [26, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [26, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [26, 'Thursday', 'Lunch', 'Party Size', 2],
# [27, 'Saturday', 'Dinner', 'Total Bill', 12.69],
# [27, 'Saturday', 'Dinner', 'Tip', 2],
# [27, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [27, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [27, 'Saturday', 'Dinner', 'Party Size', 2],
# [27, 'Thursday', 'Lunch', 'Total Bill', 10.07],
# [27, 'Thursday', 'Lunch', 'Tip', 1.83],
# [27, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [27, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [27, 'Thursday', 'Lunch', 'Party Size', 1],
# [27, 'Thursday', 'Lunch', 'Total Bill', 14.15],
# [27, 'Thursday', 'Lunch', 'Tip', 2],
# [27, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [27, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [27, 'Thursday', 'Lunch', 'Party Size', 2],
# [27, 'Thursday', 'Lunch', 'Total Bill', 28.44],
# [27, 'Thursday', 'Lunch', 'Tip', 2.56],
# [27, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [27, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [27, 'Thursday', 'Lunch', 'Party Size', 2],
# [28, 'Saturday', 'Dinner', 'Total Bill', 21.7],
# [28, 'Saturday', 'Dinner', 'Tip', 4.3],
# [28, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [28, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [28, 'Saturday', 'Dinner', 'Party Size', 2],
# [28, 'Thursday', 'Lunch', 'Total Bill', 32.68],
# [28, 'Thursday', 'Lunch', 'Tip', 5],
# [28, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [28, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [28, 'Thursday', 'Lunch', 'Party Size', 2],
# [28, 'Thursday', 'Lunch', 'Total Bill', 16],
# [28, 'Thursday', 'Lunch', 'Tip', 2],
# [28, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [28, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [28, 'Thursday', 'Lunch', 'Party Size', 2],
# [28, 'Thursday', 'Lunch', 'Total Bill', 15.48],
# [28, 'Thursday', 'Lunch', 'Tip', 2.02],
# [28, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [28, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [28, 'Thursday', 'Lunch', 'Party Size', 2],
# [29, 'Saturday', 'Dinner', 'Total Bill', 19.65],
# [29, 'Saturday', 'Dinner', 'Tip', 3],
# [29, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [29, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [29, 'Saturday', 'Dinner', 'Party Size', 2],
# [29, 'Thursday', 'Lunch', 'Total Bill', 15.98],
# [29, 'Thursday', 'Lunch', 'Tip', 2.03],
# [29, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [29, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [29, 'Thursday', 'Lunch', 'Party Size', 2],
# [29, 'Thursday', 'Lunch', 'Total Bill', 13.16],
# [29, 'Thursday', 'Lunch', 'Tip', 2.75],
# [29, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [29, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [29, 'Thursday', 'Lunch', 'Party Size', 2],
# [29, 'Thursday', 'Lunch', 'Total Bill', 16.58],
# [29, 'Thursday', 'Lunch', 'Tip', 4],
# [29, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [29, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [29, 'Thursday', 'Lunch', 'Party Size', 2],
# [30, 'Saturday', 'Dinner', 'Total Bill', 9.55],
# [30, 'Saturday', 'Dinner', 'Tip', 1.45],
# [30, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [30, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [30, 'Saturday', 'Dinner', 'Party Size', 2],
# [30, 'Thursday', 'Lunch', 'Total Bill', 34.83],
# [30, 'Thursday', 'Lunch', 'Tip', 5.17],
# [30, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [30, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [30, 'Thursday', 'Lunch', 'Party Size', 4],
# [30, 'Thursday', 'Lunch', 'Total Bill', 17.47],
# [30, 'Thursday', 'Lunch', 'Tip', 3.5],
# [30, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [30, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [30, 'Thursday', 'Lunch', 'Party Size', 2],
# [30, 'Thursday', 'Lunch', 'Total Bill', 7.56],
# [30, 'Thursday', 'Lunch', 'Tip', 1.44],
# [30, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [30, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [30, 'Thursday', 'Lunch', 'Party Size', 2],
# [31, 'Saturday', 'Dinner', 'Total Bill', 18.35],
# [31, 'Saturday', 'Dinner', 'Tip', 2.5],
# [31, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [31, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [31, 'Saturday', 'Dinner', 'Party Size', 4],
# [31, 'Thursday', 'Lunch', 'Total Bill', 13.03],
# [31, 'Thursday', 'Lunch', 'Tip', 2],
# [31, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [31, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [31, 'Thursday', 'Lunch', 'Party Size', 2],
# [31, 'Thursday', 'Lunch', 'Total Bill', 34.3],
# [31, 'Thursday', 'Lunch', 'Tip', 6.7],
# [31, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [31, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [31, 'Thursday', 'Lunch', 'Party Size', 6],
# [31, 'Thursday', 'Lunch', 'Total Bill', 10.34],
# [31, 'Thursday', 'Lunch', 'Tip', 2],
# [31, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [31, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [31, 'Thursday', 'Lunch', 'Party Size', 2],
# [32, 'Saturday', 'Dinner', 'Total Bill', 15.06],
# [32, 'Saturday', 'Dinner', 'Tip', 3],
# [32, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [32, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [32, 'Saturday', 'Dinner', 'Party Size', 2],
# [32, 'Thursday', 'Lunch', 'Total Bill', 18.28],
# [32, 'Thursday', 'Lunch', 'Tip', 4],
# [32, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [32, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [32, 'Thursday', 'Lunch', 'Party Size', 2],
# [32, 'Thursday', 'Lunch', 'Total Bill', 41.19],
# [32, 'Thursday', 'Lunch', 'Tip', 5],
# [32, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [32, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [32, 'Thursday', 'Lunch', 'Party Size', 5],
# [32, 'Thursday', 'Lunch', 'Total Bill', 43.11],
# [32, 'Thursday', 'Lunch', 'Tip', 5],
# [32, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [32, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [32, 'Thursday', 'Lunch', 'Party Size', 4],
# [33, 'Saturday', 'Dinner', 'Total Bill', 20.69],
# [33, 'Saturday', 'Dinner', 'Tip', 2.45],
# [33, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [33, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [33, 'Saturday', 'Dinner', 'Party Size', 4],
# [33, 'Thursday', 'Lunch', 'Total Bill', 24.71],
# [33, 'Thursday', 'Lunch', 'Tip', 5.85],
# [33, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [33, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [33, 'Thursday', 'Lunch', 'Party Size', 2],
# [33, 'Thursday', 'Lunch', 'Total Bill', 27.05],
# [33, 'Thursday', 'Lunch', 'Tip', 5],
# [33, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [33, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [33, 'Thursday', 'Lunch', 'Party Size', 6],
# [33, 'Thursday', 'Lunch', 'Total Bill', 13],
# [33, 'Thursday', 'Lunch', 'Tip', 2],
# [33, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [33, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [33, 'Thursday', 'Lunch', 'Party Size', 2],
# [34, 'Saturday', 'Dinner', 'Total Bill', 17.78],
# [34, 'Saturday', 'Dinner', 'Tip', 3.27],
# [34, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [34, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [34, 'Saturday', 'Dinner', 'Party Size', 2],
# [34, 'Thursday', 'Lunch', 'Total Bill', 21.16],
# [34, 'Thursday', 'Lunch', 'Tip', 3],
# [34, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [34, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [34, 'Thursday', 'Lunch', 'Party Size', 2],
# [34, 'Thursday', 'Lunch', 'Total Bill', 16.43],
# [34, 'Thursday', 'Lunch', 'Tip', 2.3],
# [34, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [34, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [34, 'Thursday', 'Lunch', 'Party Size', 2],
# [34, 'Thursday', 'Lunch', 'Total Bill', 13.51],
# [34, 'Thursday', 'Lunch', 'Tip', 2],
# [34, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [34, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [34, 'Thursday', 'Lunch', 'Party Size', 2],
# [35, 'Saturday', 'Dinner', 'Total Bill', 24.06],
# [35, 'Saturday', 'Dinner', 'Tip', 3.6],
# [35, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [35, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [35, 'Saturday', 'Dinner', 'Party Size', 3],
# [35, 'Friday', 'Dinner', 'Total Bill', 28.97],
# [35, 'Friday', 'Dinner', 'Tip', 3],
# [35, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
# [35, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [35, 'Friday', 'Dinner', 'Party Size', 2],
# [35, 'Thursday', 'Lunch', 'Total Bill', 8.35],
# [35, 'Thursday', 'Lunch', 'Tip', 1.5],
# [35, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [35, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [35, 'Thursday', 'Lunch', 'Party Size', 2],
# [35, 'Thursday', 'Lunch', 'Total Bill', 18.71],
# [35, 'Thursday', 'Lunch', 'Tip', 4],
# [35, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [35, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [35, 'Thursday', 'Lunch', 'Party Size', 3],
# [36, 'Saturday', 'Dinner', 'Total Bill', 16.31],
# [36, 'Saturday', 'Dinner', 'Tip', 2],
# [36, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [36, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [36, 'Saturday', 'Dinner', 'Party Size', 3],
# [36, 'Friday', 'Dinner', 'Total Bill', 22.49],
# [36, 'Friday', 'Dinner', 'Tip', 3.5],
# [36, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
# [36, 'Friday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [36, 'Friday', 'Dinner', 'Party Size', 2],
# [36, 'Thursday', 'Lunch', 'Total Bill', 18.64],
# [36, 'Thursday', 'Lunch', 'Tip', 1.36],
# [36, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [36, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [36, 'Thursday', 'Lunch', 'Party Size', 3],
# [36, 'Thursday', 'Lunch', 'Total Bill', 12.74],
# [36, 'Thursday', 'Lunch', 'Tip', 2.01],
# [36, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [36, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [36, 'Thursday', 'Lunch', 'Party Size', 2],
# [37, 'Saturday', 'Dinner', 'Total Bill', 16.93],
# [37, 'Saturday', 'Dinner', 'Tip', 3.07],
# [37, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [37, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [37, 'Saturday', 'Dinner', 'Party Size', 3],
# [37, 'Friday', 'Dinner', 'Total Bill', 5.75],
# [37, 'Friday', 'Dinner', 'Tip', 1],
# [37, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
# [37, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [37, 'Friday', 'Dinner', 'Party Size', 2],
# [37, 'Thursday', 'Lunch', 'Total Bill', 11.87],
# [37, 'Thursday', 'Lunch', 'Tip', 1.63],
# [37, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [37, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [37, 'Thursday', 'Lunch', 'Party Size', 2],
# [37, 'Thursday', 'Lunch', 'Total Bill', 13],
# [37, 'Thursday', 'Lunch', 'Tip', 2],
# [37, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [37, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [37, 'Thursday', 'Lunch', 'Party Size', 2],
# [38, 'Saturday', 'Dinner', 'Total Bill', 18.69],
# [38, 'Saturday', 'Dinner', 'Tip', 2.31],
# [38, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [38, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [38, 'Saturday', 'Dinner', 'Party Size', 3],
# [38, 'Friday', 'Dinner', 'Total Bill', 16.32],
# [38, 'Friday', 'Dinner', 'Tip', 4.3],
# [38, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
# [38, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [38, 'Friday', 'Dinner', 'Party Size', 2],
# [38, 'Thursday', 'Lunch', 'Total Bill', 9.78],
# [38, 'Thursday', 'Lunch', 'Tip', 1.73],
# [38, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [38, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [38, 'Thursday', 'Lunch', 'Party Size', 2],
# [38, 'Thursday', 'Lunch', 'Total Bill', 16.4],
# [38, 'Thursday', 'Lunch', 'Tip', 2.5],
# [38, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [38, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [38, 'Thursday', 'Lunch', 'Party Size', 2],
# [39, 'Saturday', 'Dinner', 'Total Bill', 31.27],
# [39, 'Saturday', 'Dinner', 'Tip', 5],
# [39, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [39, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [39, 'Saturday', 'Dinner', 'Party Size', 3],
# [39, 'Friday', 'Dinner', 'Total Bill', 22.75],
# [39, 'Friday', 'Dinner', 'Tip', 3.25],
# [39, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
# [39, 'Friday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [39, 'Friday', 'Dinner', 'Party Size', 2],
# [39, 'Thursday', 'Lunch', 'Total Bill', 7.51],
# [39, 'Thursday', 'Lunch', 'Tip', 2],
# [39, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [39, 'Thursday', 'Lunch', 'Payer Smoker', 'Non-Smoker'],
# [39, 'Thursday', 'Lunch', 'Party Size', 2],
# [39, 'Thursday', 'Lunch', 'Total Bill', 20.53],
# [39, 'Thursday', 'Lunch', 'Tip', 4],
# [39, 'Thursday', 'Lunch', 'Payer Gender', 'Male'],
# [39, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [39, 'Thursday', 'Lunch', 'Party Size', 4],
# [40, 'Saturday', 'Dinner', 'Total Bill', 16.04],
# [40, 'Saturday', 'Dinner', 'Tip', 2.24],
# [40, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [40, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [40, 'Saturday', 'Dinner', 'Party Size', 3],
# [40, 'Friday', 'Dinner', 'Total Bill', 40.17],
# [40, 'Friday', 'Dinner', 'Tip', 4.73],
# [40, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
# [40, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [40, 'Friday', 'Dinner', 'Party Size', 4],
# [40, 'Sunday', 'Dinner', 'Total Bill', 14.07],
# [40, 'Sunday', 'Dinner', 'Tip', 2.5],
# [40, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [40, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [40, 'Sunday', 'Dinner', 'Party Size', 2],
# [40, 'Thursday', 'Lunch', 'Total Bill', 16.47],
# [40, 'Thursday', 'Lunch', 'Tip', 3.23],
# [40, 'Thursday', 'Lunch', 'Payer Gender', 'Female'],
# [40, 'Thursday', 'Lunch', 'Payer Smoker', 'Smoker'],
# [40, 'Thursday', 'Lunch', 'Party Size', 3],
# [41, 'Sunday', 'Dinner', 'Total Bill', 17.46],
# [41, 'Sunday', 'Dinner', 'Tip', 2.54],
# [41, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [41, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [41, 'Sunday', 'Dinner', 'Party Size', 2],
# [41, 'Friday', 'Dinner', 'Total Bill', 27.28],
# [41, 'Friday', 'Dinner', 'Tip', 4],
# [41, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
# [41, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [41, 'Friday', 'Dinner', 'Party Size', 2],
# [41, 'Sunday', 'Dinner', 'Total Bill', 13.13],
# [41, 'Sunday', 'Dinner', 'Tip', 2],
# [41, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [41, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [41, 'Sunday', 'Dinner', 'Party Size', 2],
# [41, 'Saturday', 'Dinner', 'Total Bill', 26.59],
# [41, 'Saturday', 'Dinner', 'Tip', 3.41],
# [41, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [41, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [41, 'Saturday', 'Dinner', 'Party Size', 3],
# [42, 'Sunday', 'Dinner', 'Total Bill', 13.94],
# [42, 'Sunday', 'Dinner', 'Tip', 3.06],
# [42, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [42, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [42, 'Sunday', 'Dinner', 'Party Size', 2],
# [42, 'Friday', 'Dinner', 'Total Bill', 12.03],
# [42, 'Friday', 'Dinner', 'Tip', 1.5],
# [42, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
# [42, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [42, 'Friday', 'Dinner', 'Party Size', 2],
# [42, 'Sunday', 'Dinner', 'Total Bill', 17.26],
# [42, 'Sunday', 'Dinner', 'Tip', 2.74],
# [42, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [42, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [42, 'Sunday', 'Dinner', 'Party Size', 3],
# [42, 'Saturday', 'Dinner', 'Total Bill', 38.73],
# [42, 'Saturday', 'Dinner', 'Tip', 3],
# [42, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [42, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [42, 'Saturday', 'Dinner', 'Party Size', 4],
# [43, 'Sunday', 'Dinner', 'Total Bill', 9.68],
# [43, 'Sunday', 'Dinner', 'Tip', 1.32],
# [43, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [43, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [43, 'Sunday', 'Dinner', 'Party Size', 2],
# [43, 'Friday', 'Dinner', 'Total Bill', 21.01],
# [43, 'Friday', 'Dinner', 'Tip', 3],
# [43, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
# [43, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [43, 'Friday', 'Dinner', 'Party Size', 2],
# [43, 'Sunday', 'Dinner', 'Total Bill', 24.55],
# [43, 'Sunday', 'Dinner', 'Tip', 2],
# [43, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [43, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [43, 'Sunday', 'Dinner', 'Party Size', 4],
# [43, 'Saturday', 'Dinner', 'Total Bill', 24.27],
# [43, 'Saturday', 'Dinner', 'Tip', 2.03],
# [43, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [43, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [43, 'Saturday', 'Dinner', 'Party Size', 2],
# [44, 'Sunday', 'Dinner', 'Total Bill', 30.4],
# [44, 'Sunday', 'Dinner', 'Tip', 5.6],
# [44, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [44, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [44, 'Sunday', 'Dinner', 'Party Size', 4],
# [44, 'Friday', 'Dinner', 'Total Bill', 12.46],
# [44, 'Friday', 'Dinner', 'Tip', 1.5],
# [44, 'Friday', 'Dinner', 'Payer Gender', 'Male'],
# [44, 'Friday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [44, 'Friday', 'Dinner', 'Party Size', 2],
# [44, 'Sunday', 'Dinner', 'Total Bill', 19.77],
# [44, 'Sunday', 'Dinner', 'Tip', 2],
# [44, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [44, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [44, 'Sunday', 'Dinner', 'Party Size', 4],
# [44, 'Saturday', 'Dinner', 'Total Bill', 12.76],
# [44, 'Saturday', 'Dinner', 'Tip', 2.23],
# [44, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [44, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [44, 'Saturday', 'Dinner', 'Party Size', 2],
# [45, 'Sunday', 'Dinner', 'Total Bill', 18.29],
# [45, 'Sunday', 'Dinner', 'Tip', 3],
# [45, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [45, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [45, 'Sunday', 'Dinner', 'Party Size', 2],
# [45, 'Friday', 'Dinner', 'Total Bill', 11.35],
# [45, 'Friday', 'Dinner', 'Tip', 2.5],
# [45, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
# [45, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [45, 'Friday', 'Dinner', 'Party Size', 2],
# [45, 'Sunday', 'Dinner', 'Total Bill', 29.85],
# [45, 'Sunday', 'Dinner', 'Tip', 5.14],
# [45, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [45, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [45, 'Sunday', 'Dinner', 'Party Size', 5],
# [45, 'Saturday', 'Dinner', 'Total Bill', 30.06],
# [45, 'Saturday', 'Dinner', 'Tip', 2],
# [45, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [45, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [45, 'Saturday', 'Dinner', 'Party Size', 3],
# [46, 'Sunday', 'Dinner', 'Total Bill', 22.23],
# [46, 'Sunday', 'Dinner', 'Tip', 5],
# [46, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [46, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [46, 'Sunday', 'Dinner', 'Party Size', 2],
# [46, 'Friday', 'Dinner', 'Total Bill', 15.38],
# [46, 'Friday', 'Dinner', 'Tip', 3],
# [46, 'Friday', 'Dinner', 'Payer Gender', 'Female'],
# [46, 'Friday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [46, 'Friday', 'Dinner', 'Party Size', 2],
# [46, 'Sunday', 'Dinner', 'Total Bill', 48.17],
# [46, 'Sunday', 'Dinner', 'Tip', 5],
# [46, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [46, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [46, 'Sunday', 'Dinner', 'Party Size', 6],
# [46, 'Saturday', 'Dinner', 'Total Bill', 25.89],
# [46, 'Saturday', 'Dinner', 'Tip', 5.16],
# [46, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [46, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [46, 'Saturday', 'Dinner', 'Party Size', 4],
# [47, 'Sunday', 'Dinner', 'Total Bill', 32.4],
# [47, 'Sunday', 'Dinner', 'Tip', 6],
# [47, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [47, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [47, 'Sunday', 'Dinner', 'Party Size', 4],
# [47, 'Saturday', 'Dinner', 'Total Bill', 44.3],
# [47, 'Saturday', 'Dinner', 'Tip', 2.5],
# [47, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [47, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [47, 'Saturday', 'Dinner', 'Party Size', 3],
# [47, 'Sunday', 'Dinner', 'Total Bill', 25],
# [47, 'Sunday', 'Dinner', 'Tip', 3.75],
# [47, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [47, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [47, 'Sunday', 'Dinner', 'Party Size', 4],
# [47, 'Saturday', 'Dinner', 'Total Bill', 48.33],
# [47, 'Saturday', 'Dinner', 'Tip', 9],
# [47, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [47, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [47, 'Saturday', 'Dinner', 'Party Size', 4],
# [48, 'Sunday', 'Dinner', 'Total Bill', 28.55],
# [48, 'Sunday', 'Dinner', 'Tip', 2.05],
# [48, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [48, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [48, 'Sunday', 'Dinner', 'Party Size', 3],
# [48, 'Saturday', 'Dinner', 'Total Bill', 22.42],
# [48, 'Saturday', 'Dinner', 'Tip', 3.48],
# [48, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [48, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [48, 'Saturday', 'Dinner', 'Party Size', 2],
# [48, 'Sunday', 'Dinner', 'Total Bill', 13.39],
# [48, 'Sunday', 'Dinner', 'Tip', 2.61],
# [48, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [48, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [48, 'Sunday', 'Dinner', 'Party Size', 2],
# [48, 'Saturday', 'Dinner', 'Total Bill', 13.27],
# [48, 'Saturday', 'Dinner', 'Tip', 2.5],
# [48, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [48, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [48, 'Saturday', 'Dinner', 'Party Size', 2],
# [49, 'Sunday', 'Dinner', 'Total Bill', 18.04],
# [49, 'Sunday', 'Dinner', 'Tip', 3],
# [49, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [49, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [49, 'Sunday', 'Dinner', 'Party Size', 2],
# [49, 'Saturday', 'Dinner', 'Total Bill', 20.92],
# [49, 'Saturday', 'Dinner', 'Tip', 4.08],
# [49, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [49, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [49, 'Saturday', 'Dinner', 'Party Size', 2],
# [49, 'Sunday', 'Dinner', 'Total Bill', 16.49],
# [49, 'Sunday', 'Dinner', 'Tip', 2],
# [49, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [49, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [49, 'Sunday', 'Dinner', 'Party Size', 4],
# [49, 'Saturday', 'Dinner', 'Total Bill', 28.17],
# [49, 'Saturday', 'Dinner', 'Tip', 6.5],
# [49, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [49, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [49, 'Saturday', 'Dinner', 'Party Size', 3],
# [50, 'Sunday', 'Dinner', 'Total Bill', 12.54],
# [50, 'Sunday', 'Dinner', 'Tip', 2.5],
# [50, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [50, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [50, 'Sunday', 'Dinner', 'Party Size', 2],
# [50, 'Saturday', 'Dinner', 'Total Bill', 15.36],
# [50, 'Saturday', 'Dinner', 'Tip', 1.64],
# [50, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [50, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [50, 'Saturday', 'Dinner', 'Party Size', 2],
# [50, 'Sunday', 'Dinner', 'Total Bill', 21.5],
# [50, 'Sunday', 'Dinner', 'Tip', 3.5],
# [50, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [50, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [50, 'Sunday', 'Dinner', 'Party Size', 4],
# [50, 'Saturday', 'Dinner', 'Total Bill', 12.9],
# [50, 'Saturday', 'Dinner', 'Tip', 1.1],
# [50, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [50, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [50, 'Saturday', 'Dinner', 'Party Size', 2],
# [51, 'Sunday', 'Dinner', 'Total Bill', 10.29],
# [51, 'Sunday', 'Dinner', 'Tip', 2.6],
# [51, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [51, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [51, 'Sunday', 'Dinner', 'Party Size', 2],
# [51, 'Saturday', 'Dinner', 'Total Bill', 20.49],
# [51, 'Saturday', 'Dinner', 'Tip', 4.06],
# [51, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [51, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [51, 'Saturday', 'Dinner', 'Party Size', 2],
# [51, 'Sunday', 'Dinner', 'Total Bill', 12.66],
# [51, 'Sunday', 'Dinner', 'Tip', 2.5],
# [51, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [51, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [51, 'Sunday', 'Dinner', 'Party Size', 2],
# [51, 'Saturday', 'Dinner', 'Total Bill', 28.15],
# [51, 'Saturday', 'Dinner', 'Tip', 3],
# [51, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [51, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [51, 'Saturday', 'Dinner', 'Party Size', 5],
# [52, 'Sunday', 'Dinner', 'Total Bill', 34.81],
# [52, 'Sunday', 'Dinner', 'Tip', 5.2],
# [52, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [52, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [52, 'Sunday', 'Dinner', 'Party Size', 4],
# [52, 'Saturday', 'Dinner', 'Total Bill', 25.21],
# [52, 'Saturday', 'Dinner', 'Tip', 4.29],
# [52, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [52, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [52, 'Saturday', 'Dinner', 'Party Size', 2],
# [52, 'Sunday', 'Dinner', 'Total Bill', 16.21],
# [52, 'Sunday', 'Dinner', 'Tip', 2],
# [52, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [52, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [52, 'Sunday', 'Dinner', 'Party Size', 3],
# [52, 'Saturday', 'Dinner', 'Total Bill', 11.59],
# [52, 'Saturday', 'Dinner', 'Tip', 1.5],
# [52, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [52, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [52, 'Saturday', 'Dinner', 'Party Size', 2],
# [53, 'Sunday', 'Dinner', 'Total Bill', 9.94],
# [53, 'Sunday', 'Dinner', 'Tip', 1.56],
# [53, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [53, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [53, 'Sunday', 'Dinner', 'Party Size', 2],
# [53, 'Saturday', 'Dinner', 'Total Bill', 18.24],
# [53, 'Saturday', 'Dinner', 'Tip', 3.76],
# [53, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [53, 'Saturday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [53, 'Saturday', 'Dinner', 'Party Size', 2],
# [53, 'Sunday', 'Dinner', 'Total Bill', 13.81],
# [53, 'Sunday', 'Dinner', 'Tip', 2],
# [53, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [53, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [53, 'Sunday', 'Dinner', 'Party Size', 2],
# [53, 'Saturday', 'Dinner', 'Total Bill', 7.74],
# [53, 'Saturday', 'Dinner', 'Tip', 1.44],
# [53, 'Saturday', 'Dinner', 'Payer Gender', 'Male'],
# [53, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [53, 'Saturday', 'Dinner', 'Party Size', 2],
# [54, 'Sunday', 'Dinner', 'Total Bill', 25.56],
# [54, 'Sunday', 'Dinner', 'Tip', 4.34],
# [54, 'Sunday', 'Dinner', 'Payer Gender', 'Male'],
# [54, 'Sunday', 'Dinner', 'Payer Smoker', 'Non-Smoker'],
# [54, 'Sunday', 'Dinner', 'Party Size', 4],
# [54, 'Saturday', 'Dinner', 'Total Bill', 14.31],
# [54, 'Saturday', 'Dinner', 'Tip', 4],
# [54, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [54, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [54, 'Saturday', 'Dinner', 'Party Size', 2],
# [54, 'Sunday', 'Dinner', 'Total Bill', 17.51],
# [54, 'Sunday', 'Dinner', 'Tip', 3],
# [54, 'Sunday', 'Dinner', 'Payer Gender', 'Female'],
# [54, 'Sunday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [54, 'Sunday', 'Dinner', 'Party Size', 2],
# [54, 'Saturday', 'Dinner', 'Total Bill', 30.14],
# [54, 'Saturday', 'Dinner', 'Tip', 3.09],
# [54, 'Saturday', 'Dinner', 'Payer Gender', 'Female'],
# [54, 'Saturday', 'Dinner', 'Payer Smoker', 'Smoker'],
# [54, 'Saturday', 'Dinner', 'Party Size', 4],

# %%
df.head(20)
# Out:
#     record_id  total bill day of week     attribute       value
# 0           0       16.99      Sunday           Tip        1.01
# 1           0       16.99      Sunday  Payer Gender      Female
# 2           0       16.99      Sunday  Payer Smoker  Non-Smoker
# 3           0       16.99      Sunday          Meal      Dinner
# 4           0       16.99      Sunday    Party Size           2
# 5           1       10.34      Sunday           Tip        1.66
# 6           1       10.34      Sunday  Payer Gender        Male
# 7           1       10.34      Sunday  Payer Smoker  Non-Smoker
# 8           1       10.34      Sunday          Meal      Dinner
# 9           1       10.34      Sunday    Party Size           3
# 10          2       21.01      Sunday           Tip         3.5
# 11          2       21.01      Sunday  Payer Gender        Male
# 12          2       21.01      Sunday  Payer Smoker  Non-Smoker
# 13          2       21.01      Sunday          Meal      Dinner
# 14          2       21.01      Sunday    Party Size           3
# 15          3       23.68      Sunday           Tip        3.31
# 16          3       23.68      Sunday  Payer Gender        Male
# 17          3       23.68      Sunday  Payer Smoker  Non-Smoker
# 18          3       23.68      Sunday          Meal      Dinner
# 19          3       23.68      Sunday    Party Size           2
